# %% [markdown]
# ## Background
# Using information we scrape from the web, build linear regression models from which we can learn about movies, sports, or categories.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
import requests
from bs4 import BeautifulSoup
import time

# %%
from datetime import date
from datetime import datetime
import calendar
from dateutil.parser import parse

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

import chromedriver_binary

# driver = webdriver.Chrome()

# matrix_url = url
# driver.get(matrix_url)

# %% [markdown]
# ### Scrape the following attributes from Hotel.com
#
#  * Check in Date
#  * Check out Date
#  * Adults
#  * Children
#  * Hotel_Name
#  * Hotel_Address
#  * Las Vegas - General Area
#  * Property_Landmarks
#  * Amenities
#  * Review Box
#  * Number of Hotel.com Guest Reviews
#  * Trip Advisor Rating
#  * Number of Trip Advisor Reviews
#  * Slashed Price - nightly price per room
#  * Sales Price - nightly price per room
#  * Deals - Free Cancellation

# %%
def get_soup(url):    
    
    '''
    Takes an url from Hotel.com and 
    infinitely scrolls down to end of page
    until no more content can be loaded.
    '''
    # Open up chrome in incognito
#     chrome_options = webdriver.ChromeOptions()
#     chrome_options.add_argument("--incognito")

    driver = webdriver.Chrome()

    # Nagivate to url 
    driver.get(url)
    
    # Scroll down until the end of the page
    has_scrolled_count = 0
    
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            
        for attempt in range(20):
            try:
                if driver.find_element_by_id("listings-loading").value_of_css_property("display") == "block":
                    has_scrolled_count = 0
                else:
                    time.sleep(0.05)
                    has_scrolled_count += 1
            except:
                continue

            
        if any([cur_elem.is_displayed() for cur_elem in driver.find_elements_by_class_name("info")]):
            break

        if has_scrolled_count > 20:
            break
            
    # Grabs the html of the fully scrolled-down page and parse it with BeautifulSoup  
    innerHTML = driver.execute_script('return document.body.innerHTML')
    soup = BeautifulSoup(innerHTML, 'lxml')
    driver.close()
    
#     driver.execute_script("return document.innerHtml;")
#     soup = BeautifulSoup(driver.page_source, "html.parser")
    
    return soup;

# %%
def generate_url_children(checkin_date, checkout_date, adults = '2', children = '2'):
    url = 'https://www.hotels.com/search.do?resolved-location=CITY%3A1504033%3AUNKNOWN%3AUNKNOWN&destination-id=1504033&q-destination=Las%20Vegas,%20Nevada,%20United%20States%20of%20America&q-check-in='+checkin_date+'&q-check-out='+ checkout_date+'&q-rooms=1&q-room-0-adults='+ adults+'&q-room-0-children='+ children +'&q-room-0-child-0-age=8&q-room-0-child-1-age=12'
    return url

# %%
def generate_url(checkin_date, checkout_date, adults, children):
    
    url = 'https://www.hotels.com/search.do?resolved-location=CITY%3A1504033%3AUNKNOWN%3AUNKNOWN&destination-id=1504033&q-destination=Las%20Vegas,%20Nevada,%20United%20States%20of%20America&q-check-in='+checkin_date+'&q-check-out='+ checkout_date+'&q-rooms=1&q-room-0-adults='+ adults+'&q-room-0-children='+ children

    return url

# %%
Feature_html_details = {'Hotel_Name': ('h3', 'p-name'),
                        'Hotel_Add': ('span', 'address'),
                        'Hotel_LV': ('a', 'map-link xs-welcome-rewards'),
                        'Hotel_Property_Landmarks': ('ul', 'property-landmarks'),
                        'Hotel_Amenities': ('ul', 'hmvt8258-amenities'),
                        'Hotel_Details': ('div', 'additional-details resp-module'),
                        'Hotel_Review_Box': ('div', 'details resp-module'),
                        'Hotel_Num_Hotel_Reviews': ('span', 'full-view'),
                        'Hotel_TA_Rating': ('div', 'ta-logo'),
                        'Hotel_Num_TA_Reviews': ('div','ta-total-reviews'),
                        'Hotel_Price': ('aside', 'pricing resp-module')}

# %%
def get_content_list(soup, tag, class_):
    raw = soup.find_all(tag, {'class': class_})
    raw_list = [content.text for content in raw]
    return raw_list

# %%
def get_attributes(soup, checkin, checkout, adults, children):
    
#     headers = ['name', 'address', 'property_landmarks', 
#                'amenities', 'review_box', 'num_guest_reviews', 
#                'ta_ratings', 'num_ta_reviews', 'price']

#     headers = ['name', 'address', 'property_landmarks', 
#                'amenities', 'review_box', 'price', 'Checkin', 'Checkout', 'Adults', 'Children']
    headers = ['name', 'address', 'hotel_details', 'review_box', 'price', 'Checkin', 'Checkout', 'Adults', 'Children']
    
    Name = get_content_list(soup, Feature_html_details['Hotel_Name'][0], Feature_html_details['Hotel_Name'][1])
    Address = get_content_list(soup, Feature_html_details['Hotel_Add'][0], Feature_html_details['Hotel_Add'][1])
    Details = get_content_list(soup, Feature_html_details['Hotel_Details'][0], Feature_html_details['Hotel_Details'][1])
#     Property_Landmarks = get_content_list(soup, Feature_html_details['Hotel_Property_Landmarks'][0], Feature_html_details['Hotel_Property_Landmarks'][1])
#     Amenities = get_content_list(soup, Feature_html_details['Hotel_Amenities'][0], Feature_html_details['Hotel_Amenities'][1])
    Review_Box = get_content_list(soup, Feature_html_details['Hotel_Review_Box'][0], Feature_html_details['Hotel_Review_Box'][1])
#     Num_Guest_Reviews = get_content_list(Feature_html_details['Hotel_Num_Hotel_Reviews'][0], Feature_html_details['Hotel_Num_Hotel_Reviews'][1])
#     TA_Ratings = get_content_list(Feature_html_details['Hotel_TA_Rating'][0], Feature_html_details['Hotel_TA_Rating'][1])
#     Num_TA_Reviews = get_content_list(Feature_html_details['Hotel_Num_TA_Reviews'][0], Feature_html_details['Hotel_Num_TA_Reviews'][1])
    Price = get_content_list(soup, Feature_html_details['Hotel_Price'][0], Feature_html_details['Hotel_Price'][1])
    Checkin_date = [checkin] * len(Name)
    Checkout_date = [checkout] * len(Name)
    Num_Adults = [adults] * len(Name)
    Num_Children = [children] * len(Name)
    
    print('Name', len(Name))
    print('Address',len(Address))
    print('Hotel_Details', len(Details))
#     print('Property',len(Property_Landmarks))
#     print('Amenities',len(Amenities))
    print('Review_Box',len(Review_Box))
#     print('Num guest review',len(Num_Guest_Reviews))
#     print('TA_Rating',len(TA_Ratings))
#     print('num TA Review',len(Num_TA_Reviews))
    print('price',len(Price))
    

    hotel_dict = dict(zip(headers, [Name,
                                    Address,
                                    Details,
#                                     Property_Landmarks,
#                                     Amenities, 
                                    Review_Box,
#                                     Num_Guest_Reviews,
#                                     TA_Ratings,
#                                     Num_TA_Reviews,
                                    Price, Checkin_date, Checkout_date, Num_Adults, Num_Children]))
    
    hotel_df = pd.DataFrame(hotel_dict)
    print(f'{checkin} and {checkout} is successful!', hotel_df.shape)
    return hotel_df

# %%
list_checkin = ['2019-11-01', '2019-11-04', '2019-11-06', '2019-11-08', '2019-11-11', '2019-11-13',
                '2019-11-15', '2019-11-18', '2019-11-20', '2019-11-22', '2019-11-25', '2019-11-27',
                '2019-11-29', '2019-12-02', '2019-12-04', '2019-12-06', '2019-12-09', '2019-12-11',
                '2019-12-13', '2019-12-16', '2019-12-18', '2019-12-20', '2019-12-23', '2019-12-25',
                '2019-12-27', '2019-12-30', '2020-01-03', '2020-01-06', '2020-01-08', '2020-01-10']

list_checkout = ['2019-11-03', '2019-11-06', '2019-11-08', '2019-11-10', '2019-11-13', '2019-11-15',
                 '2019-11-17', '2019-11-20', '2019-11-22', '2019-11-24', '2019-11-27', '2019-11-29',
                 '2019-12-01', '2019-12-04', '2019-12-06', '2019-12-08', '2019-12-11', '2019-12-13',
                 '2019-12-15', '2019-12-18', '2019-12-20', '2019-12-22', '2019-12-25', '2019-12-27',
                 '2019-12-29', '2020-01-01', '2020-01-05', '2020-01-08', '2020-01-10', '2020-01-12']

dates_list = []
for checkin, checkout in zip(list_checkin, list_checkout):
    dates_list.append((checkin, checkout))

# %%
def combine_df_child(dates, adults = '2', children = '2'):
    
    combined_hotel_df = pd.DataFrame()
    
    for date in dates:
        url = generate_url_children(date[0], date[1], adults, children)
        soup = get_soup(url)
        partial_df = get_attributes(soup, date[0], date[1], adults, children)
        combined_hotel_df = pd.concat([combined_hotel_df, partial_df], ignore_index = True)
            
    print(f'This dataset has {combined_hotel_df.shape[0]} rows and {combined_hotel_df.shape[0]} columns')
    return combined_hotel_df

# %%
def combine_df(dates, adults = '2', children = '0'):
    
    combined_hotel_df = pd.DataFrame()
    
    for date in dates:
        url = generate_url(date[0], date[1], adults, children)
        soup = get_soup(url)
        partial_df = get_attributes(soup, date[0], date[1], adults, children)
        combined_hotel_df = pd.concat([combined_hotel_df, partial_df], ignore_index = True)
            
    print(f'This dataset has {combined_hotel_df.shape[0]} rows and {combined_hotel_df.shape[0]} columns')
    return combined_hotel_df

# %% [markdown]
# Let's grab three different data frames from 2019-11-01 through 2020-01-12 for Adults and Children of (2, 2), (4, 0), (2, 0)

# %%
# raw_hotel_2_2 = combine_df_child(dates_list, '2', '2');
# raw_hotel_2_2.to_pickle('raw_hotel_2_2.pkl');
# test_pickle_df = pd.read_pickle("raw_hotel_2_2.pkl");

# %%
# raw_hotel_4_0 = combine_df(dates_list, '4', '0')
# raw_hotel_4_0.to_pickle('raw_hotel_4_0.pkl');
# test_pickle_df = pd.read_pickle("raw_hotel_4_0.pkl");

# %%
# raw_hotel_2_0 = combine_df(dates_list, '2', '0')
# raw_hotel_2_0.to_pickle('raw_hotel_2_0.pkl');
# test_pickle_df = pd.read_pickle("raw_hotel_4_0.pkl");

# %% [markdown]
# Let's concatenate all these data frames together to form the full raw dataset

# %%
# raw_hotel = pd.concat([raw_hotel_2_2, raw_hotel_4_0, raw_hotel_2_0], ignore_index = True)
# Let's pickle this dataframe
# raw_hotel.to_pickle('raw_hotel.pkl');

# %%
raw_hotel = pd.read_pickle('raw_hotel.pkl')

# %%
raw_hotel.head()
# Out:
#                                     name  \
# 0       Sam's Town Hotel & Gambling Hall
# 1     JW Marriott Las Vegas Resort & Spa
# 2  TI - Treasure Island Hotel and Casino
# 3                         Platinum Hotel
# 4        Eastside Cannery Casino & Hotel
#
#                                              address  \
# 0  5111 Boulder Hwy, Las Vegas, NV, 89122, United...
# 1  221 N Rampart Blvd, Las Vegas, NV, 89144, Unit...
# 2  3300 Las Vegas Blvd S, Las Vegas, NV, 89109, U...
# 3  211 E Flamingo Rd, Las Vegas, NV, 89169, Unite...
# 4  5255 Boulder Hwy, Las Vegas, NV, 89122, United...
#
#                                        hotel_details  \
# 0  Las Vegas6.2 miles to City center5.3 miles to ...
# 1  Summerlin7.6 miles to City center8.1 miles to ...
# 2  Las Vegas Strip0.6 miles to City center1.2 mil...
# 3  Las Vegas0.5 miles to City center1.3 miles to ...
# 4  Las Vegas6.4 miles to City center5.5 miles to ...
#
#                                           review_box  \
# 0  Las Vegas6.2 miles to City center5.3 miles to ...
# 1  Summerlin7.6 miles to City center8.1 miles to ...
# 2  Las Vegas Strip0.6 miles to City center1.2 mil...
# 3  Las Vegas0.5 miles to City center1.3 miles to ...
# 4  Las Vegas6.4 miles to City center5.5 miles to ...
#
#                                                price     Checkin    Checkout  \
# 0  $115$86nightly price per roomThis is the avera...  2019-11-01  2019-11-03
# 1  Great Rate*The price comparison is based on pr...  2019-11-01  2019-11-03
# 2  Special DealSave 24%$262$184nightly price per ...  2019-11-01  2019-11-03
# 3  Fully booked! We’re sold out for your travel d...  2019-11-01  2019-11-03
# 4  Special DealSave 25%$99$74nightly price per ro...  2019-11-01  2019-11-03
#
#   Adults Children
# 0      2        2
# 1      2        2
# 2      2        2
# 3      2        2
# 4      2        2

# %%
print(raw_hotel.shape)
# Out:
# (19968, 9)

# %%
raw_hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19968 entries, 0 to 19967
# Data columns (total 9 columns):
# name             19968 non-null object
# address          19968 non-null object
# hotel_details    19968 non-null object
# review_box       19968 non-null object
# price            19968 non-null object
# Checkin          19968 non-null object
# Checkout         19968 non-null object
# Adults           19968 non-null object
# Children         19968 non-null object
# dtypes: object(9)
# memory usage: 1.4+ MB

# %% [markdown]
# Let's take a look at the types of each object

# %%
for i, col in enumerate(raw_hotel.columns):
    print(f'{col} is type {type(raw_hotel.columns[i])}')
# Out:
# name is type <class 'str'>
# address is type <class 'str'>
# hotel_details is type <class 'str'>
# review_box is type <class 'str'>
# price is type <class 'str'>
# Checkin is type <class 'str'>
# Checkout is type <class 'str'>
# Adults is type <class 'str'>
# Children is type <class 'str'>

# %% [markdown]
# All of the attributes are strings, we need to extract useful information from these strings

# %%
raw_hotel.name.value_counts()
# Out:
# The Palazzo at The Venetian                           133
# Wynn Las Vegas                                        129
# Waldorf Astoria Las Vegas                             122
# ARIA Resort & Casino                                  120
# Bellagio                                              114
# Luxor Hotel and Casino                                 95
# JW Marriott Las Vegas Resort & Spa                     95
# Tahiti Village Resort & Spa                            90
# Palms Place Hotel and Spa at the Palms Las Vegas       90
# Tuscany Suites & Casino                                90
# New York-New York Hotel & Casino                       89
# Cancun Resort by Diamond Resorts                       89
# OYO Hotel and Casino Las Vegas                         89
# Vdara Hotel & Spa at ARIA Las Vegas                    89
# Trump International Hotel Las Vegas                    89
# Hard Rock Hotel & Casino                               89
# Jet Luxury Resorts @ The Signature Condo Hotel         89
# Mandalay Bay Resort And Casino                         89
# The Berkley Las Vegas                                  89
# Suncoast Hotel and Casino                              89
# The LINQ Hotel & Casino                                89
# Downtown Grand Las Vegas                               89
# Four Queens Hotel and Casino (No Resort Fee)           89
# The Orleans Hotel & Casino                             89
# Flamingo Las Vegas - Hotel & Casino                    89
# The Mirage Hotel & Casino                              89
# The Venetian Resort Las Vegas                          89
# Golden Nugget Las Vegas Hotel & Casino                 89
# The Cosmopolitan Of Las Vegas                          89
# StripViewSuites at Palms Place                         88
#                                                      ...
# 888 Convention Center Condos                           36
# Huge Home with Private Park-Like grounds               36
# Fallon Luxury Rentals at The Signature                 35
# Jockey Club Suites                                     34
# Vegas Getaway Sparkling Pool & Basketball Hoop!        33
# Fortune Hotel & Suites                                 29
# Jet Luxury at Palms Place                              27
# The Carriage House by Diamond Resorts                  27
# Hostel Cat                                             23
# 1BD1BA Apartment by Stay Together Suites               22
# American Inn Motel                                     20
# Sin City Hostel Las Vegas                              17
# Welcome House Las Vegas                                17
# Stay Together Suites 2Bd-2Ba Apartment                 16
# Milos Inn                                              15
# 2BD2B Apartment Stay Together Suites 976               13
# Signature Condos By Christopher Realty                 11
# 1Bd1Ba w BonusRM Stay Together Suites                   6
# Raintree At Polo Towers, Las Vegas                      5
# 2BD2BA Apartment by Stay Together Suites                2
# Walden Motel                                            1
# WorldMark Las Vegas - Boulevard                         1
# The Camino Retreat- Las Vegas 4 Bd With Pool!           1
# Cozy 2 Bedroom Apartment                                1
# Luxurious 6BR 7min to Las Vegas Strip                   1
# Luxurious 5BR near Las Vegas Strip                      1
# Immaculate 4bed 7min to Vegas Strip                     1
# Luxurious 4BR House with Large Pool! 8min to Strip      1
# Vdara Suites by AirPads                                 1
# Casa Novona                                             1
# Name: name, Length: 281, dtype: int64

# %% [markdown]
# ### Let's split, strip, and parse through the features to create new columns.

# %%
# ReviewBox parser
# Always keep review_temps as a variable
review_temps = [content.split('Fabulous ')[-1].split('Good ')[-1].split('Superb ')[-1].split('Exceptional ')[-1].split('Gym ')[-1].split('Conditioning')[-1].split('friendly')[-1] for content in raw_hotel_ratings['review_box']]
ta_rating_temp = [content for content in review_temps]
ta_rating_temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a6ca38eb365b> in <module>()
#       1 # ReviewBox parser
#       2 # Always keep review_temps as a variable
# ----> 3 review_temps = [content.split('Fabulous ')[-1].split('Good ')[-1].split('Superb ')[-1].split('Exceptional ')[-1].split('Gym ')[-1].split('Conditioning')[-1].split('friendly')[-1] for content in raw_hotel_ratings['review_box']]
#       4 ta_rating_temp = [content for content in review_temps]
#       5 ta_rating_temp
#
# NameError: name 'raw_hotel_ratings' is not defined

# %% [markdown]
# #### Distance to city center

# %%
temp_distance = [content.split('Collect nightsCollect')[0] for content in raw_hotels_city_center['hotel_details']]
City_Center = [content.split(' Center') for content in temp_distance]
City_Center
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3034f7ad0b4c> in <module>()
# ----> 1 temp_distance = [content.split('Collect nightsCollect')[0] for content in raw_hotels_city_center['hotel_details']]
#       2 City_Center = [content.split(' Center') for content in temp_distance]
#       3 City_Center
#
# NameError: name 'raw_hotels_city_center' is not defined

# %%
raw_hotels_city_center = raw_hotel.copy()
# raw_hotels_city_center['distance_city_center'] = [content.split('miles')[0][-4:].strip(' ') for content in raw_hotel.hotel_details]

# %% [markdown]
# #### Distance to Convention Center

# %%
raw_hotels_convention_center = raw_hotels_city_center.copy()
raw_hotels_convention_center['distance_convention_center'] = [content.split('Center')[0].split('Las Vegas Convention')[0][-13:].split('miles')[0].strip(' ') for content in raw_hotels_convention_center.hotel_details]

# %% [markdown]
# #### Zip Code

# %%
raw_hotel_zip = raw_hotels_convention_center.copy()
raw_hotel_zip['zip_code'] = [content.split('NV, ')[-1].split(',')[0] for content in raw_hotels_convention_center['address']]
# [content.split('NV, ')[-1].split(',')[0] for content in raw_hotels_convention_center['address']]

# %% [markdown]
# #### Street Name

# %%
raw_hotel_street = raw_hotel_zip.copy()
raw_hotel_street['street_name'] = [' '.join(content.split(' NV')[0].split(',')[0].split(' ')[1:]) for content in raw_hotel_zip['address']]

# %%
raw_hotel_street.head()
# Out:
#                                     name  \
# 0       Sam's Town Hotel & Gambling Hall
# 1     JW Marriott Las Vegas Resort & Spa
# 2  TI - Treasure Island Hotel and Casino
# 3                         Platinum Hotel
# 4        Eastside Cannery Casino & Hotel
#
#                                              address  \
# 0  5111 Boulder Hwy, Las Vegas, NV, 89122, United...
# 1  221 N Rampart Blvd, Las Vegas, NV, 89144, Unit...
# 2  3300 Las Vegas Blvd S, Las Vegas, NV, 89109, U...
# 3  211 E Flamingo Rd, Las Vegas, NV, 89169, Unite...
# 4  5255 Boulder Hwy, Las Vegas, NV, 89122, United...
#
#                                        hotel_details  \
# 0  Las Vegas6.2 miles to City center5.3 miles to ...
# 1  Summerlin7.6 miles to City center8.1 miles to ...
# 2  Las Vegas Strip0.6 miles to City center1.2 mil...
# 3  Las Vegas0.5 miles to City center1.3 miles to ...
# 4  Las Vegas6.4 miles to City center5.5 miles to ...
#
#                                           review_box  \
# 0  Las Vegas6.2 miles to City center5.3 miles to ...
# 1  Summerlin7.6 miles to City center8.1 miles to ...
# 2  Las Vegas Strip0.6 miles to City center1.2 mil...
# 3  Las Vegas0.5 miles to City center1.3 miles to ...
# 4  Las Vegas6.4 miles to City center5.5 miles to ...
#
#                                                price     Checkin    Checkout  \
# 0  $115$86nightly price per roomThis is the avera...  2019-11-01  2019-11-03
# 1  Great Rate*The price comparison is based on pr...  2019-11-01  2019-11-03
# 2  Special DealSave 24%$262$184nightly price per ...  2019-11-01  2019-11-03
# 3  Fully booked! We’re sold out for your travel d...  2019-11-01  2019-11-03
# 4  Special DealSave 25%$99$74nightly price per ro...  2019-11-01  2019-11-03
#
#   Adults Children distance_city_center distance_convention_center zip_code  \
# 0      2        2                  6.2                        5.3    89122
# 1      2        2                  7.6                        8.1    89144
# 2      2        2                  0.6                        1.2    89109
# 3      2        2                  0.5                        1.3    89169
# 4      2        2                  6.4                        5.5    89122
#
#         street_name
# 0       Boulder Hwy
# 1    N Rampart Blvd
# 2  Las Vegas Blvd S
# 3     E Flamingo Rd
# 4       Boulder Hwy

# %% [markdown]
# #### Amenities

# %%
raw_hotel_amenities = raw_hotel_street.copy()
raw_hotel_amenities['amenities'] = [content.split('RewardsFree ')[-1].split('Center')[-1].split('Rewards')[-1] for content in raw_hotel_street['hotel_details']]

# %% [markdown]
# #### Hotel Ratings

# %%
raw_hotel_ratings = raw_hotel_amenities.copy()
raw_hotel_ratings['hotel_rating'] = temp = [content.split('Las Vegas')[-1].split(' Hotels.com® ')[-1].split(' Conditioning')[-1].split('Rewards')[-1].split('Gym')[-1].split(' ')[0] for content in raw_hotel_amenities['review_box']]

# %%
raw_hotel_ratings['hotel_rating'].value_counts();

# %% [markdown]
# #### Hotel Reviews

# %%
raw_hotel_guest_rating = raw_hotel_ratings.copy()
review_temps = [content.split('Fabulous ')[-1].split('Good ')[-1].split('Superb ')[-1].split('Exceptional ')[-1].split('Gym ')[-1].split('Conditioning')[-1].split('friendly')[-1] for content in raw_hotel_ratings['review_box']]
raw_hotel_guest_rating['hotel_reviews'] = [content.split('Hotels.com® Rewards')[-1][:3] for content in review_temps]

# %% [markdown]
# #### Number of Hotel Guest Ratings

# %%
raw_hotel_num_guest_rating = raw_hotel_guest_rating.copy()
raw_hotel_num_guest_rating['hotel_num_guest_reviews'] = [content.split(' Hotels.com guest')[0].split('reviews')[-1] for content in review_temps]

# %% [markdown]
# #### Number of TripAdvisor Reviews

# %%
raw_hotel_num_ta_reviews = raw_hotel_num_guest_rating.copy()
raw_hotel_num_ta_reviews['num_ta_reviews'] = [content.split('Rating: ')[-1].split(' reviews')[0].split('.')[-1][1:] for content in review_temps]

# %% [markdown]
# #### TripAdvisor Reviews

# %%
# For every empty element, replace with '?'
for index, content in enumerate(ta_rating_temp):
    if content == '':
        ta_rating_temp[index] = '?'

# Initial empty list
ta_rating_temp_list = []

# For every element append the rating based on different logics
for content in ta_rating_temp:
    if content == '?':
        ta_rating_temp_list.append(content)
    elif '.' in content:
        ta_rating_temp_list.append(content[:3])
    elif '.' not in content:
        ta_rating_temp_list.append(content[0])
    else:
        ta_rating_temp.append(content)    
print(len(ta_rating_temp_list))
# Out:
# 19968

# %%
raw_hotel_ta_reviews = raw_hotel_num_ta_reviews.copy()
raw_hotel_ta_reviews['ta_reviews'] = ta_rating_temp_list

# %% [markdown]
# #### Price

# %%
# trunate down the text to only show price tags
price_temp = [content.split('nightly price per')[0]
        .split('days.')[-1].split('%')[-1]
        .split('at')[-1].split('save!')[-1]
        .split('.')[-1].split(')')[-1]
        .split('!')[-1].split('free')[-1] for content in raw_hotel['price']]

price_split = [content.split('$') for content in price_temp]

# Initial empty lists for slashed and sales price
slashed_price_list = []
sales_price_list = []

# append the price based on conditions
for content in price_split:
    if len(content) == 1:
        slashed_price_list.append(np.NaN)
        sales_price_list.append(np.NaN)
    elif len(content) == 2:
        slashed_price_list.append(np.NaN)
        sales_price_list.append(content[-1])
    else:
        slashed_price_list.append(content[-2])
        sales_price_list.append(content[-1])

raw_hotel_price = raw_hotel_ta_reviews.copy()
raw_hotel_price['slashed_price'] = slashed_price_list

raw_hotel_price['sales_price'] = sales_price_list

# %% [markdown]
# #### We are finally down extracting values from the columns.
# #### These are all the features we have so far:
#
# * Checkin Date
# * Checkout Date
# * Number of Adults
# * Number of Children
# * distances from city center
# * distance from convention center
# * zip code
# * street name
# * Amenities
# * Hotel Ratings
# * Hotel Reviews
# * Number of Hotel guess reviews
# * Number of TripAdvisor Reviews
# * Trip Advisor Reviews
# * Slashed Price
# * Sales Price
#
# ##### It is important to pickle this data so we can use it later

# %%
# raw_hotel_price.to_pickle('hotel_df_uncleaned.pkl')

# %%
hotel_df_uncleaned = pd.read_pickle('hotel_df_uncleaned.pkl')

# %%
hotel_df_uncleaned.head()
# Out:
#                                     name  \
# 0       Sam's Town Hotel & Gambling Hall
# 1     JW Marriott Las Vegas Resort & Spa
# 2  TI - Treasure Island Hotel and Casino
# 3                         Platinum Hotel
# 4        Eastside Cannery Casino & Hotel
#
#                                              address  \
# 0  5111 Boulder Hwy, Las Vegas, NV, 89122, United...
# 1  221 N Rampart Blvd, Las Vegas, NV, 89144, Unit...
# 2  3300 Las Vegas Blvd S, Las Vegas, NV, 89109, U...
# 3  211 E Flamingo Rd, Las Vegas, NV, 89169, Unite...
# 4  5255 Boulder Hwy, Las Vegas, NV, 89122, United...
#
#                                        hotel_details  \
# 0  Las Vegas6.2 miles to City center5.3 miles to ...
# 1  Summerlin7.6 miles to City center8.1 miles to ...
# 2  Las Vegas Strip0.6 miles to City center1.2 mil...
# 3  Las Vegas0.5 miles to City center1.3 miles to ...
# 4  Las Vegas6.4 miles to City center5.5 miles to ...
#
#                                           review_box  \
# 0  Las Vegas6.2 miles to City center5.3 miles to ...
# 1  Summerlin7.6 miles to City center8.1 miles to ...
# 2  Las Vegas Strip0.6 miles to City center1.2 mil...
# 3  Las Vegas0.5 miles to City center1.3 miles to ...
# 4  Las Vegas6.4 miles to City center5.5 miles to ...
#
#                                                price     Checkin    Checkout  \
# 0  $115$86nightly price per roomThis is the avera...  2019-11-01  2019-11-03
# 1  Great Rate*The price comparison is based on pr...  2019-11-01  2019-11-03
# 2  Special DealSave 24%$262$184nightly price per ...  2019-11-01  2019-11-03
# 3  Fully booked! We’re sold out for your travel d...  2019-11-01  2019-11-03
# 4  Special DealSave 25%$99$74nightly price per ro...  2019-11-01  2019-11-03
#
#   Adults Children distance_city_center  ... hotel_rating hotel_reviews  \
# 0      2        2                  6.2  ...     Fabulous           8.6
# 1      2        2                  7.6  ...         Free           8.8
# 2      2        2                  0.6  ...         Very           8.2
# 3      2        2                  0.5  ...     Fabulous           8.8
# 4      2        2                  6.4  ...         Very           8.4
#
#   hotel_num__guest_reviews num_ta_reviews ta_reviews slashed_price  \
# 0                    2,339          2,114          4           115
# 1                      312          2,316          4           349
# 2                   18,827         16,513          4           262
# 3                    1,279          4,061        4.5           NaN
# 4                    2,588            871          4            99
#
#   sales_price Checkin_Day Checkout_Day When_in_Week
# 0          86      Friday       Sunday      Weekend
# 1         199      Friday       Sunday      Weekend
# 2         184      Friday       Sunday      Weekend
# 3         NaN      Friday       Sunday      Weekend
# 4          74      Friday       Sunday      Weekend
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Let's continue on with data preprocessing

# %% [markdown]
# We will extract datetime objects from the checkin and checkout dates. Here is how we can do this:
#
# 1. We need to extract the datetime objects from the checkin and checkout strings
# 2. Use the datetime object and calender.day_name attribute to determine the day of the week
# 3. Make two new columns for Checkin Day and Checkout Day

# %%
hotel_df_uncleaned_datetime = hotel_df_uncleaned.copy()

# Extract the datetime object from checkin and checkout strings
checkin_datetime = [datetime.strptime(content, '%Y-%m-%d') for content in hotel_df_uncleaned['Checkin']]
checkout_datetime = [datetime.strptime(content, '%Y-%m-%d') for content in hotel_df_uncleaned['Checkout']]

Checkin_Day = [calendar.day_name[content.weekday()] for content in checkin_datetime]
Checkout_Day = [calendar.day_name[content.weekday()] for content in checkout_datetime] 

hotel_df_uncleaned_datetime['Checkin_Day'] = Checkin_Day
hotel_df_uncleaned_datetime['Checkout_Day'] = Checkout_Day

# %% [markdown]
# Let's put some context to these checkin and checkout days by categorizing it to be either:
# * Friday through Sunday - Weekend
# * Monday through Wednesday - Beginning of Week
# * Wednesday through Friday - End of Week

# %%
hotel_df_uncleaned_weekly_categories = hotel_df_uncleaned_datetime.copy()

# Initital an empty list 
When_in_Week = []
for day in Checkin_Day:
    if day == 'Friday':
        When_in_Week.append('Weekend')
    if day == 'Monday':
        When_in_Week.append('Beginning of Week')
    if day == 'Wednesday':
        When_in_Week.append('End of Week')

hotel_df_uncleaned_weekly_categories['When_in_Week'] = When_in_Week

# %% [markdown]
# ## Pickle Checkpoint

# %%
# hotel_df_uncleaned_weekly_categories.to_pickle('hotel_df_uncleaned.pkl')

# %%
hotel_df_uncleaned = pd.read_pickle('hotel_df_uncleaned.pkl')
hotel_df_uncleaned.head();
hotel_df_uncleaned.rename(columns= {'hotel_num__guest_reviews': 'hotel_num_guest_reviews'}, inplace = True);

# %% [markdown]
# #### Let's clean up the slashed and sales price columns

# %%
print(f'There are {hotel_df_uncleaned["slashed_price"].isnull().value_counts()[1]} null values in slashed price')
# Out:
# There are 4268 null values in slashed price

# %% [markdown]
# Let's impute the slashed price with the sale's price since there is no deals for the listing

# %%
hotel_df_uncleaned['slashed_price'].fillna(hotel_df_uncleaned['sales_price'], inplace = True)
print(f'There are {hotel_df_uncleaned["slashed_price"].isnull().value_counts()[1]} null values in slashed price')
print(f'There are {hotel_df_uncleaned["sales_price"].isnull().value_counts()[1]} null values in sales price')
print(hotel_df_uncleaned.shape)
# Out:
# There are 193 null values in slashed price
# There are 193 null values in sales price
# (19968, 24)

# %% [markdown]
# Now there are equal amount of missing values in both slashed and sales price. We can just drop the hotels where there are no price. This is because the hotel for a particular hotel is totally booked!

# %%
hotel_df_dropna = hotel_df_uncleaned.dropna()
print(hotel_df_dropna.shape)
print(f'We have {round(hotel_df_dropna.shape[0]/hotel_df_uncleaned.shape[0] * 100,2)}% of the original dataset left')
# Out:
# (19775, 24)
# We have 99.03% of the original dataset left

# %% [markdown]
# We need to turn each of the price values to float values

# %%
hotel_df_price = hotel_df_dropna.copy()
hotel_df_price['slashed_price'] = [float(price.replace(',','')) for price in hotel_df_price['slashed_price']]
hotel_df_price['sales_price'] = [float(price.replace(',','')) for price in hotel_df_price['sales_price']]
hotel_df_price[['slashed_price', 'sales_price']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19775 entries, 0 to 19967
# Data columns (total 2 columns):
# slashed_price    19775 non-null float64
# sales_price      19775 non-null float64
# dtypes: float64(2)
# memory usage: 463.5 KB

# %% [markdown]
# Similarly, we need turn all the following columns to be type float:
# * ta_reviews
# * num_ta_reviews
# * hotel_num_guest_reviews
# * hotel_reviews
# * distance_city_center
# * distance_convention_center

# %%
# ta_reviews
hotel_df_float_all = hotel_df_price.copy()

possible_reviews = ['0.5', '1', '1.5', '2', '2.5', '3', '3.5', '4', '4.5', '5']

# Only return the ratings which are in the possible reviews list
hotel_df_float_all = hotel_df_float_all[hotel_df_float_all['ta_reviews'].isin(possible_reviews)]

hotel_df_float_all['ta_reviews'] = [float(content) for content in hotel_df_float_all['ta_reviews']]
print(hotel_df_float_all.shape)
print(f'We have {round(hotel_df_float_all.shape[0]/hotel_df_uncleaned.shape[0] * 100,2)}% of the original dataset left')
hotel_df_float_all['ta_reviews'].dtypes
# Out:
# (17707, 24)
# We have 88.68% of the original dataset left
# dtype('float64')

# %%
# num_ta_reviews

hotel_df_float_all2 = hotel_df_float_all.copy()
hotel_df_float_all2['num_ta_reviews'] = [float(content.replace(',','')) for content in hotel_df_float_all2['num_ta_reviews']]
print(hotel_df_float_all2.shape)
print(f'We have {round(hotel_df_float_all2.shape[0]/hotel_df_uncleaned.shape[0] * 100,2)}% of the original dataset left')
hotel_df_float_all2['num_ta_reviews'].dtypes
# Out:
# (17707, 24)
# We have 88.68% of the original dataset left
# dtype('float64')

# %%
# hotel_num_guest_reviews

hotel_df_float_all3 = hotel_df_float_all2.copy()
# Filter out all the rows with an empty string ''
hotel_df_float_all3 = hotel_df_float_all3[hotel_df_float_all3['hotel_num_guest_reviews'] != '']
hotel_df_float_all3['hotel_num_guest_reviews'] = [float(content.replace(',','')) for content in hotel_df_float_all3['hotel_num_guest_reviews']]
print(hotel_df_float_all3.shape)
print(f'We have {round(hotel_df_float_all3.shape[0]/hotel_df_uncleaned.shape[0] * 100,2)}% of the original dataset left')
hotel_df_float_all3['hotel_num_guest_reviews'].dtypes
# Out:
# (17635, 24)
# We have 88.32% of the original dataset left
# dtype('float64')

# %%
# hotel_reviews

hotel_df_float_all4 = hotel_df_float_all3.copy()

# Filter out all the rows with the value 'Fre'
hotel_df_float_all4 = hotel_df_float_all4[hotel_df_float_all4['hotel_reviews'] != 'Fre']
hotel_df_float_all4['hotel_reviews'] = [float(content) for content in hotel_df_float_all4['hotel_reviews']]
print(hotel_df_float_all4.shape)
print(f'We have {round(hotel_df_float_all4.shape[0]/hotel_df_uncleaned.shape[0] * 100,2)}% of the original dataset left')
hotel_df_float_all4['hotel_num_guest_reviews'].dtypes
# Out:
# (17603, 24)
# We have 88.16% of the original dataset left
# dtype('float64')

# %%
# distance_city_center
hotel_df_float_all5 = hotel_df_float_all4.copy()

# %%
# hotel_df_float_all5['distance_city_center'].unique()

# Made a list of elements to remove. Most of these hotels are far away from Las Vegas
list_to_remove = ['ning', 's11', 'n10', 'n11', 's10', 'n13', 'y23', 'y21', 'n25', 's14', 'n18', 's13', 'n14', 'ards']
# Return a dataframe that do not include those values
hotel_df_float_all5 = hotel_df_float_all5[hotel_df_float_all5.distance_city_center.isin(list_to_remove) == False]
hotel_df_float_all5['distance_city_center'] = [float(content) for content in hotel_df_float_all5['distance_city_center']]
print(hotel_df_float_all5.shape)
print(f'We have {round(hotel_df_float_all5.shape[0]/hotel_df_uncleaned.shape[0] * 100,2)}% of the original dataset left')
hotel_df_float_all5['distance_city_center'].dtypes
# Out:
# (16104, 24)
# We have 80.65% of the original dataset left
# dtype('float64')

# %%
list_to_remove2 = ['r1.0 mile to', 'r10']
# hotel_df_float_all5['distance_convention_center'].unique() 
hotel_df_float_all5 = hotel_df_float_all5[hotel_df_float_all5.distance_convention_center.isin(list_to_remove2) == False]
hotel_df_float_all5['distance_convention_center'] = [float(content) for content in hotel_df_float_all5['distance_convention_center']]
print(hotel_df_float_all5.shape)
print(f'We have {round(hotel_df_float_all5.shape[0]/hotel_df_uncleaned.shape[0] * 100,2)}% of the original dataset left')
hotel_df_float_all5['distance_convention_center'].dtypes
# Out:
# (15897, 24)
# We have 79.61% of the original dataset left
# dtype('float64')

# %% [markdown]
# We should turn the Adults and Children column into floats as well

# %%
hotel_df_float_all6 = hotel_df_float_all5.copy()
hotel_df_float_all6['Adults'] = [float(content) for content in hotel_df_float_all6['Adults']]
hotel_df_float_all6['Children'] = [float(content) for content in hotel_df_float_all6['Children']]
print(hotel_df_float_all6.shape)
print(f'We have {round(hotel_df_float_all6.shape[0]/hotel_df_uncleaned.shape[0] * 100,2)}% of the original dataset left')
hotel_df_float_all6[['Adults', 'Children']].info()
# Out:
# (15897, 24)
# We have 79.61% of the original dataset left
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15897 entries, 0 to 19952
# Data columns (total 2 columns):
# Adults      15897 non-null float64
# Children    15897 non-null float64
# dtypes: float64(2)
# memory usage: 372.6 KB

# %% [markdown]
# We can try to extract the amenities column. Some of the amenities we can look for are listed in the following:
# * parking
# * pool
# * gym
# * air_conditioning
# * pet-friendly
# * kitchen
# * airport transfer

# %%
hotel_df_float_all7 = hotel_df_float_all6.copy()

# %%
# Some of the amenity categories we will look for
parking = 'parking'
pool = 'pool'
gym = 'gym'
air_conditioning = 'air conditioning'
pet_friendly = 'pet-friendly'
kitchen = 'kitchen'
airport_transfer = 'airport transfer'

# %%
hotel_df_float_all7['parking'] = [1 if parking in content.lower() else 0 for content in hotel_df_float_all7['amenities']]
hotel_df_float_all7['pool'] = [1 if pool in content.lower() else 0 for content in hotel_df_float_all7['amenities']]
hotel_df_float_all7['gym'] = [1 if gym in content.lower() else 0 for content in hotel_df_float_all7['amenities']]
hotel_df_float_all7['air_conditioning'] = [1 if air_conditioning in content.lower() else 0 for content in hotel_df_float_all7['amenities']]
hotel_df_float_all7['pet_friendly'] = [1 if pet_friendly in content.lower() else 0 for content in hotel_df_float_all7['amenities']]
hotel_df_float_all7['kitchen'] = [1 if kitchen in content.lower() else 0 for content in hotel_df_float_all7['amenities']]
hotel_df_float_all7['airport_transfer'] = [1 if airport_transfer in content.lower() else 0 for content in hotel_df_float_all7['amenities']]

# %%
print(hotel_df_float_all7.shape)
print(f'We have {round(hotel_df_float_all7.shape[0]/hotel_df_uncleaned.shape[0] * 100,2)}% of the original dataset left')
hotel_df_float_all7['pool'].dtypes
# Out:
# (15897, 31)
# We have 79.61% of the original dataset left
# dtype('int64')

# %% [markdown]
# Let's finish cleaning the rest of the columns:
#
# * zip code
# * hotel ratings

# %%
hotel_df_float_all8 = hotel_df_float_all7.copy()

# %%
hotel_df_float_all8['zip_code'].unique()
# Out:
# array(['89122', '89144', '89109', '89103', '89169', '89123', '89101',
#        '89183', '89139', '89121', '89118', '89119', '89102', '89158',
#        '89145', '89014', '89052', '89107', '89130', '89030', '89104',
#        '89128', '89147', '89032', '89081', '89117', '89011', '89012',
#        '89108', '89135', '89105'], dtype=object)

# %% [markdown]
# Looks like the ZipCode column was cleaned and we do not need to do any further cleaning.

# %% [markdown]
# We want to keep only the ratings that are the following:
#
# * Exceptional
# * Superb
# * Fabulous
# * Very Good
# * Good
# * No Rating

# %%
rating_list = ['Exceptional', 'Superb', 'Fabulous', 'Very Good', 'Good']

# Turn Very to Very good
hotel_df_float_all8['hotel_rating'] = [content + ' Good' if content == 'Very' else content for content in hotel_df_float_all8['hotel_rating']]
# Clean up the ratings and include no rating for any rows for rating that is not on the rating_list
hotel_df_float_all8['hotel_rating'] = [content if content in rating_list else 'No Rating' for content in hotel_df_float_all8['hotel_rating']]

# %%
hotel_df_float_all8['hotel_rating'].value_counts()
# Out:
# Good           5046
# Fabulous       3470
# Very Good      3444
# Superb         2740
# No Rating       680
# Exceptional     517
# Name: hotel_rating, dtype: int64

# %% [markdown]
# #### Street Name
# We need to clean up and group some of the street names together

# %%
# street_dict = {'Dr': ['Dr', 'Dr.', 'Drive'],
#                'Rd': ['Rd', 'Road'],
#                'Ave': ['Ave', 'Avenue'],
#                'Blvd': ['Blvd.', 'Boulevard'],
#                'Ct': ['Ct'],
#                'Hwy': ['Hwy', 'Highway'],
#                'Ln': ['Ln', 'Lane'],
#                'North': ['North'],
#                'Pkwy': ['Parkway', 'PARKWAY', 'Pkwy'],
#                'S': ['South', 'S'],
#                'St': ['St', 'Street', 'Street'],
#                'Way': ['Way']}

# street_list = [street.split(' ')[:-1] for street in hotel_df_float_all8['street_name'].unique()]
# street_list

# %%
hotel_df_float_all7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15897 entries, 0 to 19952
# Data columns (total 31 columns):
# name                          15897 non-null object
# address                       15897 non-null object
# hotel_details                 15897 non-null object
# review_box                    15897 non-null object
# price                         15897 non-null object
# Checkin                       15897 non-null object
# Checkout                      15897 non-null object
# Adults                        15897 non-null float64
# Children                      15897 non-null float64
# distance_city_center          15897 non-null float64
# distance_convention_center    15897 non-null float64
# zip_code                      15897 non-null object
# street_name                   15897 non-null object
# amenities                     15897 non-null object
# hotel_rating                  15897 non-null object
# hotel_reviews                 15897 non-null float64
# hotel_num_guest_reviews       15897 non-null float64
# num_ta_reviews                15897 non-null float64
# ta_reviews                    15897 non-null float64
# slashed_price                 15897 non-null float64
# sales_price                   15897 non-null float64
# Checkin_Day                   15897 non-null object
# Checkout_Day                  15897 non-null object
# When_in_Week                  15897 non-null object
# parking                       15897 non-null int64
# pool                          15897 non-null int64
# gym                           15897 non-null int64
# air_conditioning              15897 non-null int64
# pet_friendly                  15897 non-null int64
# kitchen                       15897 non-null int64
# airport_transfer              15897 non-null int64
# dtypes: float64(10), int64(7), object(14)
# memory usage: 3.9+ MB

# %% [markdown]
# ### Pickle Checkpoint

# %%
# hotel_df_float_all8.to_pickle('hotel_df.pkl')
hotel_df = pd.read_pickle('hotel_df.pkl')
hotel_df.head();

# %% [markdown]
# # Exploratory Data Analysis: Hotels in Las Vegas
#
# ## Question:
# 1.  Which hotels have the highest review counts?
# 2. Which are the cloest hotels in terms of distance to the city and convention center?
# 3. What is the average hotel price during November vs December?
# 4. When is the cheapest time to travel for each hotel?
# 5. How many hotels have amenities and which hotel have none?
# 6. What are the distribution of each of these variables?

# %%
hotel_df.columns
# Out:
# Index(['name', 'address', 'hotel_details', 'review_box', 'price', 'Checkin',
#        'Checkout', 'Adults', 'Children', 'distance_city_center',
#        'distance_convention_center', 'zip_code', 'street_name', 'amenities',
#        'hotel_rating', 'hotel_reviews', 'hotel_num_guest_reviews',
#        'num_ta_reviews', 'ta_reviews', 'slashed_price', 'sales_price',
#        'Checkin_Day', 'Checkout_Day', 'When_in_Week', 'parking', 'pool', 'gym',
#        'air_conditioning', 'pet_friendly', 'kitchen', 'airport_transfer'],
#       dtype='object')

# %%
selected_columns = ['Checkin', 'Checkout', 'Adults', 'Children', 'distance_city_center', 'distance_convention_center', 'zip_code', 'hotel_rating', 
                    'hotel_reviews', 'hotel_num_guest_reviews', 'num_ta_reviews', 'ta_reviews', 
                    'sales_price', 'Checkin_Day', 'Checkout_Day','When_in_Week', 'parking', 'pool', 'gym', 'air_conditioning',
                    'pet_friendly', 'kitchen', 'airport_transfer']
sub_hotel_df = hotel_df[selected_columns]

# %%
sub_hotel_df.sample(5)
# Out:
#           Checkin    Checkout  Adults  Children  distance_city_center  \
# 15766  2019-11-29  2019-12-01     2.0       0.0                   1.7
# 6270   2020-01-10  2020-01-12     2.0       2.0                   1.3
# 3778   2019-12-13  2019-12-15     2.0       2.0                   0.5
# 14683  2019-11-18  2019-11-20     2.0       0.0                   4.9
# 3153   2019-12-06  2019-12-08     2.0       2.0                   0.5
#
#        distance_convention_center zip_code hotel_rating  hotel_reviews  \
# 15766                         3.1    89119  Exceptional            9.6
# 6270                          1.7    89169     Fabulous            8.6
# 3778                          2.0    89109         Good            6.4
# 14683                         6.4    89139         Good            6.8
# 3153                          1.1    89109       Superb            9.0
#
#        hotel_num_guest_reviews  ...  Checkin_Day  Checkout_Day  \
# 15766                    836.0  ...       Friday        Sunday
# 6270                     433.0  ...       Friday        Sunday
# 3778                    1206.0  ...       Friday        Sunday
# 14683                    118.0  ...       Monday     Wednesday
# 3153                     631.0  ...       Friday        Sunday
#
#             When_in_Week parking pool gym  air_conditioning  pet_friendly  \
# 15766            Weekend       1    1   1                 1             0
# 6270             Weekend       1    1   1                 1             1
# 3778             Weekend       1    1   0                 1             0
# 14683  Beginning of Week       1    0   0                 1             0
# 3153             Weekend       1    1   1                 1             0
#
#        kitchen  airport_transfer
# 15766        0                 0
# 6270         0                 1
# 3778         0                 0
# 14683        0                 0
# 3153         0                 0
#
# [5 rows x 23 columns]

# %%
sub_hotel_df.describe()
# Out:
#              Adults      Children  distance_city_center  \
# count  15897.000000  15897.000000          15897.000000
# mean       2.655092      0.637227              3.185406
# std        0.938666      0.931907              2.759864
# min        2.000000      0.000000              0.100000
# 25%        2.000000      0.000000              1.100000
# 50%        2.000000      0.000000              2.100000
# 75%        4.000000      2.000000              4.900000
# max        4.000000      2.000000              9.900000
#
#        distance_convention_center  hotel_reviews  hotel_num_guest_reviews  \
# count                15897.000000   15897.000000             15897.000000
# mean                     3.538775       8.060741              2731.936969
# std                      2.559087       1.037201              4580.319752
# min                      0.100000       2.000000                 2.000000
# 25%                      1.700000       7.400000               262.000000
# 50%                      2.700000       8.400000               868.000000
# 75%                      5.300000       8.800000              2463.000000
# max                      9.600000      10.000000             28121.000000
#
#        num_ta_reviews    ta_reviews   sales_price       parking          pool  \
# count    15897.000000  15897.000000  15897.000000  15897.000000  15897.000000
# mean      4620.156885      3.896018    177.950305      0.792980      0.749009
# std       8145.596795      0.556147    279.104274      0.405183      0.433597
# min          2.000000      2.000000     19.000000      0.000000      0.000000
# 25%        397.000000      3.500000     90.000000      1.000000      0.000000
# 50%       1124.000000      4.000000    131.000000      1.000000      1.000000
# 75%       3646.000000      4.500000    187.000000      1.000000      1.000000
# max      41798.000000      5.000000   9100.000000      1.000000      1.000000
#
#                 gym  air_conditioning  pet_friendly       kitchen  \
# count  15897.000000      15897.000000  15897.000000  15897.000000
# mean       0.653771          0.790527      0.120400      0.176260
# std        0.475782          0.406946      0.325439      0.381053
# min        0.000000          0.000000      0.000000      0.000000
# 25%        0.000000          1.000000      0.000000      0.000000
# 50%        1.000000          1.000000      0.000000      0.000000
# 75%        1.000000          1.000000      0.000000      0.000000
# max        1.000000          1.000000      1.000000      1.000000
#
#        airport_transfer
# count      15897.000000
# mean           0.148141
# std            0.355251
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %%
# sns.pairplot(sub_hotel_df._get_numeric_data())

# %%
def distplot(df, feature, size):
    sns.distplot(df[feature])
    plt.xlabel(f'{feature}', size = size)
    plt.title(f'The distribution of {feature}', size = size)

# %%
def find_feature_limit(df, feature):
    '''
    INPUT dataframe and feature
    Returns the lower and upper limit using IQR method
    '''
    
    q25, q50, q75 = np.percentile(df[feature], [25, 50, 75])
    IQR = q75 - q25
    
    # Calculate the max and min limits to be considered as an outlier
    
    lower = q25 - 1.5 * IQR
    upper = q75 + 1.5 * IQR
    
    return lower, upper

# %%
def distplot_filter(df, feature, size):
    '''
    Plots the distribution of a numerical feature
    from df with a upper limit constraint defined by the
    feature's upper limit using the IQR method
    '''
    upper = find_feature_limit(df, feature)[1]
    distplot(df[df[feature] < upper], feature, size)

# %%
def distplot_log(df, feature, size):  
    '''
    Plots the log distribution of a numberical feature
    from df
    '''
    sns.distplot(np.log(df[feature]))
    plt.xlabel(f'{feature}', size = size)
    plt.title(f'The log distribution of {feature}', size = size)

# %% [markdown]
# Let's visualize some of the distributions of these features

# %%
sub_hotel_df.columns
# Out:
# Index(['Checkin', 'Checkout', 'Adults', 'Children', 'distance_city_center',
#        'distance_convention_center', 'zip_code', 'hotel_rating',
#        'hotel_reviews', 'hotel_num_guest_reviews', 'num_ta_reviews',
#        'ta_reviews', 'sales_price', 'Checkin_Day', 'Checkout_Day',
#        'When_in_Week', 'parking', 'pool', 'gym', 'air_conditioning',
#        'pet_friendly', 'kitchen', 'airport_transfer'],
#       dtype='object')

# %% [markdown]
# Distribution plot of Ratings and Reviews

# %%
df = sub_hotel_df
size = 15
plt.figure(figsize = (12,8))

# hotel_reviews
plt.subplot(2,2,1)
dist_hotel_reviews =distplot(df, 'hotel_reviews', size)

# hotel_num_guest_reviews
plt.subplot(2,2,2)
dist_num_hotel_reviews = distplot(df, 'hotel_num_guest_reviews', size)


# ta_reviews
plt.subplot(2,2,3)
dist_ta_reviews = distplot(df, 'ta_reviews', size)


# num_ta_reviews
plt.subplot(2,2,4)
dist_num_ta_reviews = distplot(df, 'num_ta_reviews', size)

plt.tight_layout()

# %% [markdown]
# The distribution of reviews looks normal. We need to filter out the outliers from the review count from both the hotel and tripadvisor

# %%
df = sub_hotel_df
size = 15
plt.figure(figsize = (12,8))

# hotel_reviews
plt.subplot(2,2,1)
dist_hotel_reviews =distplot_filter(df, 'hotel_reviews', size)

# hotel_num_guest_reviews
plt.subplot(2,2,2)
dist_num_hotel_reviews = distplot_filter(df, 'hotel_num_guest_reviews', size)


# ta_reviews
plt.subplot(2,2,3)
dist_ta_reviews = distplot_filter(df, 'ta_reviews', size)


# num_ta_reviews
plt.subplot(2,2,4)
dist_num_ta_reviews = distplot_filter(df, 'num_ta_reviews', size)

plt.tight_layout()

# %% [markdown]
# The number of reviews are still skewed to the right. We can transform it by taking the logarithmic value of the non-filter values

# %%
df = sub_hotel_df
size = 15
plt.figure(figsize = (12,8))

# hotel_reviews
plt.subplot(2,2,1)
dist_hotel_reviews =distplot(df, 'hotel_reviews', size)

# hotel_num_guest_reviews
plt.subplot(2,2,2)
dist_num_hotel_reviews = distplot_log(df, 'hotel_num_guest_reviews', size)


# ta_reviews
plt.subplot(2,2,3)
dist_ta_reviews = distplot_filter(df, 'ta_reviews', size)


# num_ta_reviews
plt.subplot(2,2,4)
dist_num_ta_reviews = distplot_log(df, 'num_ta_reviews', size)

plt.tight_layout()

# %% [markdown]
# These are distributions are more 'normal' after a log transformation

# %% [markdown]
# Let's look at other columns

# %%
# Price
df = sub_hotel_df
size = 20

plt.figure(figsize = (12, 6))
plt.subplot(1,2,1)
dist_price = distplot(df, 'sales_price', size)

plt.subplot(1,2,2)
dist_logprice = distplot_log(df, 'sales_price', size)

plt.tight_layout()

# %% [markdown]
# Again, we see the transformation of the value takes a skewed distribution to a more normal distribution

# %%
# distances

df = sub_hotel_df
size = 15

plt.figure(figsize = (12, 6))
plt.subplot(2,2,1)
dist_city_center = distplot(df, 'distance_city_center', size)

plt.subplot(2,2,2)
dist_log_city_center = distplot_log(df, 'distance_city_center', size)

plt.subplot(2,2,3)
dist_convention_center = distplot(df, 'distance_convention_center', size)

plt.subplot(2,2,4)
dist_log_convention_center = distplot_log(df, 'distance_convention_center', size)

plt.tight_layout()

# %% [markdown]
# It is debetable if the log transformation helped normalize the values. We can see both versions into our preliminary model and decide from there

# %% [markdown]
# Let's find the correlation between these variables to price

# %%
sub_hotel_df_dummies = pd.get_dummies(sub_hotel_df, drop_first = True)

# %%
sub_hotel_df_dummies['log_price'] = np.log(sub_hotel_df_dummies['sales_price'])
sub_hotel_df_dummies.corr()['log_price'].sort_values(ascending = False);

# %%
checkin_datetime = [datetime.strptime(content, '%Y-%m-%d') for content in sub_hotel_df['Checkin']]
checkout_datetime = [datetime.strptime(content, '%Y-%m-%d') for content in sub_hotel_df['Checkout']]

# %%
hotel_df.columns
# Out:
# Index(['name', 'address', 'hotel_details', 'review_box', 'price', 'Checkin',
#        'Checkout', 'Adults', 'Children', 'distance_city_center',
#        'distance_convention_center', 'zip_code', 'street_name', 'amenities',
#        'hotel_rating', 'hotel_reviews', 'hotel_num_guest_reviews',
#        'num_ta_reviews', 'ta_reviews', 'slashed_price', 'sales_price',
#        'Checkin_Day', 'Checkout_Day', 'When_in_Week', 'parking', 'pool', 'gym',
#        'air_conditioning', 'pet_friendly', 'kitchen', 'airport_transfer'],
#       dtype='object')

# %%
# Average selling price per night per hotel in Las Vegas
avg_price_per_hotel = hotel_df.groupby('name')['sales_price'].mean().sort_values(ascending = False)

# %%
avg_price_per_zipcode = hotel_df.groupby('zip_code')['sales_price'].mean().sort_values(ascending = False)
avg_price_per_zipcode;

# %%
avg_price_per_date = hotel_df.groupby('Checkin')['sales_price'].mean()
avg_price_per_date

plt.figure(figsize = (12,6))
sns.lineplot(avg_price_per_date.index, avg_price_per_date);
plt.xticks(avg_price_per_date.index, rotation='vertical', size = 15);
plt.title('Average Hotel Price per Night in Las Vegas', size = 20);

# %% [markdown]
# #### Do the average nightly hotel price change depending on occupancy?
# * class 1 - 4 adults
# * class 2 - 2 adults 2 children
# * class 3 - 2 adults

# %%
class1 = hotel_df.query('Adults == 4')
class2 = hotel_df.query('Adults == 2 and Children == 2')
class3 = hotel_df.query('Adults == 2')

avg_price_class1 = class1.groupby('Checkin')['sales_price'].mean()
avg_price_class2 = class2.groupby('Checkin')['sales_price'].mean()
avg_price_class3 = class3.groupby('Checkin')['sales_price'].mean()

plt.figure(figsize = (16,8))
sns.lineplot(avg_price_class1.index, avg_price_class1, markers = True)
sns.lineplot(avg_price_class2.index, avg_price_class2, markers = True)
sns.lineplot(avg_price_class3.index, avg_price_class3, markers = True)
plt.xticks(avg_price_class1.index, rotation='vertical', size = 15);
labels=['4 Adults', '2 Adults 2 Children', '2 Adults']
plt.legend(title='Occupancy', loc='upper left', labels= labels, 
           fontsize = 'x-large', title_fontsize =20);
plt.xlabel('Checkin Dates', size = 20);
plt.ylabel('Average Price per Night (USD)', size = 20);
plt.title('Average Hotel Price per Night by Occupancy', size = 25);
plt.xlim([class1.Checkin.min(), class1.Checkin.max()]);

# %% [markdown]
# The average hotel price shares the same trend among different Occupancy types.

# %% [markdown]
# Let's find the average hotel price throughout the week.
# * weekend
# * beginning of week
# * end of week

# %%
avg_price_week = hotel_df.groupby('When_in_Week')['sales_price'].mean()
plt.figure(figsize = (10,4))
sns.barplot(avg_price_week.index, avg_price_week)
plt.title('Avgerage Hotel Price per Night', size = 20);
plt.xlabel('')
plt.ylabel('Average Nightly Price (USD)', size = 15);

# %% [markdown]
# #### Does the hotel and tripadvisor reviews mean the hotel can price their rooms higher?

# %%
hotel_df.columns
# Out:
# Index(['name', 'address', 'hotel_details', 'review_box', 'price', 'Checkin',
#        'Checkout', 'Adults', 'Children', 'distance_city_center',
#        'distance_convention_center', 'zip_code', 'street_name', 'amenities',
#        'hotel_rating', 'hotel_reviews', 'hotel_num_guest_reviews',
#        'num_ta_reviews', 'ta_reviews', 'slashed_price', 'sales_price',
#        'Checkin_Day', 'Checkout_Day', 'When_in_Week', 'parking', 'pool', 'gym',
#        'air_conditioning', 'pet_friendly', 'kitchen', 'airport_transfer'],
#       dtype='object')

# %%
plt.figure(figsize = (10,10))
label = ['Number of Hotel.com Reviews', 'Number of TripAdvisor Reviews']
plt.subplot(2,2,1)
sns.scatterplot(x = 'hotel_num_guest_reviews', y = 'sales_price', data = hotel_df);
plt.xlabel('Number of Guest Reviews')
plt.ylabel('Hotel Price (USD)')
plt.subplot(2,2,2)
sns.scatterplot(x = 'num_ta_reviews', y = 'sales_price', data = hotel_df);
plt.xlabel('Number of TripAdvisor Reviews')
plt.ylabel('Hotel Price (USD)')

plt.subplot(2,2,3)
sns.scatterplot(x = 'hotel_reviews', y = 'sales_price', data = hotel_df);
plt.xlabel('Hotel.com Guest Review')
plt.ylabel('Hotel Price (USD)')
plt.subplot(2,2,4)
sns.scatterplot(x = 'ta_reviews', y = 'sales_price', data = hotel_df);
plt.xlabel('TripAdvisor Reviews')
plt.ylabel('Hotel Price (USD)')

plt.tight_layout()

# %% [markdown]
# ## Model

# %% [markdown]
# Let's feed our initial values into a simple linear regression model

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge, Lasso, RidgeCV, LassoCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.model_selection import GridSearchCV
from sklearn import linear_model

# %% [markdown]
# #### Stats Model

# %%
import statsmodels.api as sm

# %%
hotel_df = pd.read_pickle('hotel_df.pkl')

# %%
selected_features = ['Checkin', 'Checkout', 'Adults', 'Children', 'distance_city_center',
       'distance_convention_center', 'zip_code', 'hotel_rating',
       'hotel_reviews', 'hotel_num_guest_reviews', 'num_ta_reviews',
       'ta_reviews', 'Checkin_Day', 'Checkout_Day', 'sales_price',
       'When_in_Week', 'parking', 'pool', 'gym', 'air_conditioning',
       'pet_friendly', 'kitchen', 'airport_transfer']

# %% [markdown]
# Let's get dummies for for the categorical data using pd.get_dummies
#
# Somethings to change:
# * we need to take the logarithmic transformation of price, hotel_num_guest_reviews, and num_ta_reviews

# %%
sub_hotel_df_dummies = pd.get_dummies(sub_hotel_df, drop_first = True)
sub_hotel_df_dummies['log_hotel_num_guest_reviews'] = np.log(sub_hotel_df_dummies.hotel_num_guest_reviews)
sub_hotel_df_dummies['log_num_ta_reviews'] = np.log(sub_hotel_df_dummies.num_ta_reviews)
sub_hotel_df_dummies['log_price'] = np.log(sub_hotel_df_dummies.sales_price)


y = np.log(sub_hotel_df_dummies.sales_price)
X = sub_hotel_df_dummies.drop(['sales_price', 
                               'log_price'], 1)

statsmodel = sm.OLS(y,X)
fit_model = statsmodel.fit()
fit_model.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                       Results: Ordinary least squares
# ============================================================================
# Model:                 OLS                 Adj. R-squared:        0.606
# Dependent Variable:    sales_price         AIC:                   19201.3119
# Date:                  2019-10-08 16:29    BIC:                   19830.5705
# No. Observations:      15897               Log-Likelihood:        -9518.7
# Df Model:              81                  F-statistic:           302.9
# Df Residuals:          15815               Prob (F-statistic):    0.00
# R-squared:             0.608               Scale:                 0.19492
# ----------------------------------------------------------------------------
#                              Coef.  Std.Err.    t     P>|t|   [0.025  0.975]
# ----------------------------------------------------------------------------
# Adults                       0.1004   0.0043  23.5580 0.0000  0.0921  0.1088
# Children                     0.0631   0.0043  14.6432 0.0000  0.0547  0.0716
# distance_city_center        -0.0855   0.0069 -12.4162 0.0000 -0.0990 -0.0720
# distance_convention_center   0.0551   0.0065   8.4943 0.0000  0.0424  0.0679
# hotel_reviews                0.0886   0.0106   8.3844 0.0000  0.0679  0.1093
# hotel_num_guest_reviews     -0.0000   0.0000  -7.6169 0.0000 -0.0000 -0.0000
# num_ta_reviews               0.0000   0.0000  17.2200 0.0000  0.0000  0.0000
# ta_reviews                   0.1380   0.0130  10.6109 0.0000  0.1125  0.1635
# parking                     -0.1687   0.0228  -7.4111 0.0000 -0.2134 -0.1241
# pool                        -0.1427   0.0166  -8.6141 0.0000 -0.1751 -0.1102
# gym                          0.0138   0.0141   0.9780 0.3281 -0.0139  0.0416
# air_conditioning             0.3600   0.0245  14.6648 0.0000  0.3119  0.4081
# pet_friendly                -0.0074   0.0121  -0.6142 0.5391 -0.0312  0.0163
# kitchen                     -0.1422   0.0112 -12.6794 0.0000 -0.1642 -0.1202
# airport_transfer            -0.0449   0.0125  -3.6077 0.0003 -0.0694 -0.0205
# Checkin_2019-11-04           0.3920   0.0114  34.2368 0.0000  0.3695  0.4144
# Checkin_2019-11-06           0.5195   0.0116  44.8009 0.0000  0.4968  0.5423
# Checkin_2019-11-08           0.0016   0.0136   0.1151 0.9083 -0.0250  0.0282
# Checkin_2019-11-11           0.0566   0.0104   5.4595 0.0000  0.0363  0.0770
# Checkin_2019-11-13           0.0978   0.0107   9.1043 0.0000  0.0768  0.1189
# Checkin_2019-11-15          -0.1234   0.0133  -9.2479 0.0000 -0.1495 -0.0972
# Checkin_2019-11-18           0.0343   0.0102   3.3439 0.0008  0.0142  0.0543
# Checkin_2019-11-20           0.0747   0.0106   7.0228 0.0000  0.0538  0.0955
# Checkin_2019-11-22          -0.1832   0.0140 -13.1285 0.0000 -0.2106 -0.1559
# Checkin_2019-11-25          -0.0321   0.0103  -3.1214 0.0018 -0.0522 -0.0119
# Checkin_2019-11-27           0.0757   0.0117   6.4957 0.0000  0.0529  0.0986
# Checkin_2019-11-29          -0.1454   0.0138 -10.5721 0.0000 -0.1723 -0.1184
# Checkin_2019-12-02           0.1081   0.0118   9.1936 0.0000  0.0851  0.1311
# Checkin_2019-12-04           0.1706   0.0109  15.7196 0.0000  0.1493  0.1918
# Checkin_2019-12-06          -0.1166   0.0135  -8.6165 0.0000 -0.1432 -0.0901
# Checkin_2019-12-09           0.0650   0.0103   6.3086 0.0000  0.0448  0.0852
# Checkin_2019-12-11           0.0715   0.0108   6.6370 0.0000  0.0504  0.0927
# Checkin_2019-12-13          -0.1914   0.0133 -14.3593 0.0000 -0.2175 -0.1653
# Checkin_2019-12-16          -0.0317   0.0104  -3.0570 0.0022 -0.0520 -0.0114
# Checkin_2019-12-18          -0.0024   0.0106  -0.2241 0.8227 -0.0231  0.0183
# Checkin_2019-12-20          -0.2703   0.0133 -20.3781 0.0000 -0.2963 -0.2443
# Checkin_2019-12-23          -0.0126   0.0104  -1.2118 0.2256 -0.0330  0.0078
# Checkin_2019-12-25           0.0397   0.0107   3.7262 0.0002  0.0188  0.0606
# Checkin_2019-12-27          -0.1255   0.0136  -9.1992 0.0000 -0.1522 -0.0987
# Checkin_2019-12-30           0.5449   0.0109  50.0553 0.0000  0.5235  0.5662
# Checkin_2020-01-03          -0.2254   0.0134 -16.8742 0.0000 -0.2516 -0.1992
# Checkin_2020-01-06           0.6311   0.0116  54.3965 0.0000  0.6083  0.6538
# Checkin_2020-01-08           0.6868   0.0118  57.9662 0.0000  0.6636  0.7101
# Checkin_2020-01-10          -0.0803   0.0140  -5.7429 0.0000 -0.1077 -0.0529
# Checkout_2019-11-06          0.3920   0.0114  34.2368 0.0000  0.3695  0.4144
# Checkout_2019-11-08          0.5195   0.0116  44.8009 0.0000  0.4968  0.5423
# Checkout_2019-11-10          0.0016   0.0136   0.1151 0.9083 -0.0250  0.0282
# Checkout_2019-11-13          0.0566   0.0104   5.4595 0.0000  0.0363  0.0770
# Checkout_2019-11-15          0.0978   0.0107   9.1043 0.0000  0.0768  0.1189
# Checkout_2019-11-17         -0.1234   0.0133  -9.2479 0.0000 -0.1495 -0.0972
# Checkout_2019-11-20          0.0343   0.0102   3.3439 0.0008  0.0142  0.0543
# Checkout_2019-11-22          0.0747   0.0106   7.0228 0.0000  0.0538  0.0955
# Checkout_2019-11-24         -0.1832   0.0140 -13.1285 0.0000 -0.2106 -0.1559
# Checkout_2019-11-27         -0.0321   0.0103  -3.1214 0.0018 -0.0522 -0.0119
# Checkout_2019-11-29          0.0757   0.0117   6.4957 0.0000  0.0529  0.0986
# Checkout_2019-12-01         -0.1454   0.0138 -10.5721 0.0000 -0.1723 -0.1184
# Checkout_2019-12-04          0.1081   0.0118   9.1936 0.0000  0.0851  0.1311
# Checkout_2019-12-06          0.1706   0.0109  15.7196 0.0000  0.1493  0.1918
# Checkout_2019-12-08         -0.1166   0.0135  -8.6165 0.0000 -0.1432 -0.0901
# Checkout_2019-12-11          0.0650   0.0103   6.3086 0.0000  0.0448  0.0852
# Checkout_2019-12-13          0.0715   0.0108   6.6370 0.0000  0.0504  0.0927
# Checkout_2019-12-15         -0.1914   0.0133 -14.3593 0.0000 -0.2175 -0.1653
# Checkout_2019-12-18         -0.0317   0.0104  -3.0570 0.0022 -0.0520 -0.0114
# Checkout_2019-12-20         -0.0024   0.0106  -0.2241 0.8227 -0.0231  0.0183
# Checkout_2019-12-22         -0.2703   0.0133 -20.3781 0.0000 -0.2963 -0.2443
# Checkout_2019-12-25         -0.0126   0.0104  -1.2118 0.2256 -0.0330  0.0078
# Checkout_2019-12-27          0.0397   0.0107   3.7262 0.0002  0.0188  0.0606
# Checkout_2019-12-29         -0.1255   0.0136  -9.1992 0.0000 -0.1522 -0.0987
# Checkout_2020-01-01          0.5449   0.0109  50.0553 0.0000  0.5235  0.5662
# Checkout_2020-01-05         -0.2254   0.0134 -16.8742 0.0000 -0.2516 -0.1992
# Checkout_2020-01-08          0.6311   0.0116  54.3965 0.0000  0.6083  0.6538
# Checkout_2020-01-10          0.6868   0.0118  57.9662 0.0000  0.6636  0.7101
# Checkout_2020-01-12         -0.0803   0.0140  -5.7429 0.0000 -0.1077 -0.0529
# zip_code_89012               0.5047   0.0635   7.9505 0.0000  0.3802  0.6291
# zip_code_89014               0.2511   0.0560   4.4832 0.0000  0.1413  0.3608
# zip_code_89030               0.2330   0.0584   3.9923 0.0001  0.1186  0.3473
# zip_code_89032               0.0542   0.0752   0.7215 0.4706 -0.0931  0.2016
# zip_code_89052               0.3003   0.0572   5.2493 0.0000  0.1882  0.4124
# zip_code_89081               0.2168   0.0586   3.6993 0.0002  0.1019  0.3317
# zip_code_89101               0.1922   0.0649   2.9613 0.0031  0.0650  0.3193
# zip_code_89102               0.1715   0.0743   2.3087 0.0210  0.0259  0.3171
# zip_code_89103               0.1834   0.0711   2.5814 0.0098  0.0441  0.3227
# zip_code_89104               0.0100   0.0697   0.1432 0.8862 -0.1266  0.1466
# zip_code_89105               0.1324   0.0959   1.3800 0.1676 -0.0556  0.3204
# zip_code_89107              -0.0509   0.0797  -0.6386 0.5231 -0.2070  0.1053
# zip_code_89108               0.3374   0.0743   4.5398 0.0000  0.1917  0.4830
# zip_code_89109               0.3407   0.0732   4.6578 0.0000  0.1973  0.4841
# zip_code_89117               0.3105   0.0645   4.8135 0.0000  0.1841  0.4369
# zip_code_89118               0.1766   0.0692   2.5510 0.0108  0.0409  0.3122
# zip_code_89119               0.2214   0.0679   3.2626 0.0011  0.0884  0.3544
# zip_code_89121              -0.0007   0.0652  -0.0105 0.9916 -0.1286  0.1272
# zip_code_89122               0.2835   0.0629   4.5095 0.0000  0.1603  0.4067
# zip_code_89123               0.2149   0.0633   3.3939 0.0007  0.0908  0.3390
# zip_code_89128               0.2318   0.0637   3.6368 0.0003  0.1069  0.3567
# zip_code_89130              -0.0939   0.0758  -1.2391 0.2153 -0.2424  0.0546
# zip_code_89135               0.4412   0.0738   5.9806 0.0000  0.2966  0.5858
# zip_code_89139              -0.0389   0.0627  -0.6193 0.5357 -0.1619  0.0841
# zip_code_89144               0.3421   0.0718   4.7625 0.0000  0.2013  0.4829
# zip_code_89145               0.1815   0.0727   2.4955 0.0126  0.0389  0.3241
# zip_code_89147               0.0889   0.0642   1.3861 0.1657 -0.0368  0.2147
# zip_code_89158               1.2233   0.0797  15.3409 0.0000  1.0670  1.3796
# zip_code_89169               0.2713   0.0745   3.6400 0.0003  0.1252  0.4174
# zip_code_89183               0.4535   0.0651   6.9607 0.0000  0.3258  0.5812
# hotel_rating_Fabulous       -0.0505   0.0242  -2.0853 0.0371 -0.0980 -0.0030
# hotel_rating_Good           -0.1718   0.0325  -5.2880 0.0000 -0.2355 -0.1081
# hotel_rating_No Rating       0.4487   0.0447  10.0492 0.0000  0.3612  0.5363
# hotel_rating_Superb          0.0226   0.0235   0.9589 0.3376 -0.0235  0.0686
# hotel_rating_Very Good      -0.1196   0.0265  -4.5193 0.0000 -0.1714 -0.0677
# Checkin_Day_Monday           1.7555   0.0547  32.0845 0.0000  1.6483  1.8628
# Checkin_Day_Wednesday        1.7340   0.0541  32.0435 0.0000  1.6280  1.8401
# Checkout_Day_Sunday          2.1394   0.0610  35.0825 0.0000  2.0199  2.2589
# Checkout_Day_Wednesday       1.7555   0.0547  32.0845 0.0000  1.6483  1.8628
# When_in_Week_End of Week     1.7340   0.0541  32.0435 0.0000  1.6280  1.8401
# When_in_Week_Weekend         2.1394   0.0610  35.0825 0.0000  2.0199  2.2589
# log_hotel_num_guest_reviews -0.1365   0.0040 -34.0094 0.0000 -0.1444 -0.1286
# log_num_ta_reviews           0.0258   0.0044   5.9103 0.0000  0.0173  0.0344
# ----------------------------------------------------------------------------
# Omnibus:              1898.493      Durbin-Watson:         1.773
# Prob(Omnibus):        0.000         Jarque-Bera (JB):      5862.449
# Skew:                 0.627         Prob(JB):              0.000
# Kurtosis:             5.698         Condition No.:         11559362768238006
# ============================================================================
# * The condition number is large (1e+16). This might indicate
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# * FE_distance_city_center - 1 divided by the distance to city center
# * FE_distance_convention_center - 1 divided by the distance to city center
# * FE_distance_city_convention - distances of city center * convention center

# %%
sub_hotel_df_FE = sub_hotel_df.copy()
sub_hotel_df_FE['FE_distance_city_center'] = 1 / sub_hotel_df_FE.distance_city_center
sub_hotel_df_FE['FE_distance_convention_center'] = 1 / sub_hotel_df_FE.distance_convention_center
sub_hotel_df_FE['distance_city_convention'] = (sub_hotel_df_FE.distance_city_center * sub_hotel_df_FE.distance_convention_center)

# %%
sub_hotel_df_dummies2 = pd.get_dummies(sub_hotel_df_FE, drop_first = True)
# sub_hotel_df_dummies2['log_distances'] = np.log(sub_hotel_df_FE.distance_city_convention)
sub_hotel_df_dummies2['log_hotel_num_guest_reviews'] = np.log(sub_hotel_df_dummies2.hotel_num_guest_reviews)
sub_hotel_df_dummies2['log_num_ta_reviews'] = np.log(sub_hotel_df_dummies2.num_ta_reviews)
sub_hotel_df_dummies2['log_price'] = np.log(sub_hotel_df_dummies2.sales_price)


y = sub_hotel_df_dummies2.log_price
X = sub_hotel_df_dummies2.drop(['sales_price',
                               'log_price', 
                               'hotel_num_guest_reviews',
                               'num_ta_reviews'], 1)

statsmodel2 = sm.OLS(y,X)
fit_model2 = statsmodel2.fit()
fit_model2.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                        Results: Ordinary least squares
# ==============================================================================
# Model:                   OLS                 Adj. R-squared:        0.602
# Dependent Variable:      log_price           AIC:                   19365.8577
# Date:                    2019-10-09 08:32    BIC:                   20002.7903
# No. Observations:        15897               Log-Likelihood:        -9599.9
# Df Model:                82                  F-statistic:           294.2
# Df Residuals:            15814               Prob (F-statistic):    0.00
# R-squared:               0.604               Scale:                 0.19694
# ------------------------------------------------------------------------------
#                                Coef.  Std.Err.    t     P>|t|   [0.025  0.975]
# ------------------------------------------------------------------------------
# Adults                         0.1002   0.0043  23.3803 0.0000  0.0918  0.1086
# Children                       0.0624   0.0043  14.3903 0.0000  0.0539  0.0709
# distance_city_center          -0.0360   0.0116  -3.1033 0.0019 -0.0587 -0.0133
# distance_convention_center     0.0938   0.0100   9.3670 0.0000  0.0742  0.1134
# hotel_reviews                  0.0890   0.0106   8.3804 0.0000  0.0682  0.1099
# ta_reviews                     0.1469   0.0133  11.0120 0.0000  0.1207  0.1730
# parking                       -0.1785   0.0229  -7.8085 0.0000 -0.2233 -0.1337
# pool                          -0.1708   0.0165 -10.3247 0.0000 -0.2032 -0.1384
# gym                            0.0126   0.0142   0.8829 0.3773 -0.0153  0.0404
# air_conditioning               0.3954   0.0245  16.1094 0.0000  0.3473  0.4435
# pet_friendly                   0.0058   0.0121   0.4792 0.6318 -0.0180  0.0296
# kitchen                       -0.1465   0.0113 -12.9428 0.0000 -0.1686 -0.1243
# airport_transfer              -0.0520   0.0128  -4.0680 0.0000 -0.0771 -0.0270
# FE_distance_city_center        0.0365   0.0033  10.9389 0.0000  0.0299  0.0430
# FE_distance_convention_center  0.0085   0.0049   1.7424 0.0815 -0.0011  0.0181
# distance_city_convention      -0.0107   0.0018  -5.9517 0.0000 -0.0142 -0.0072
# Checkin_2019-11-04             0.3898   0.0116  33.7403 0.0000  0.3672  0.4125
# Checkin_2019-11-06             0.5168   0.0117  44.1144 0.0000  0.4938  0.5398
# Checkin_2019-11-08             0.0045   0.0136   0.3275 0.7433 -0.0223  0.0312
# Checkin_2019-11-11             0.0542   0.0105   5.1676 0.0000  0.0336  0.0747
# Checkin_2019-11-13             0.0942   0.0109   8.6683 0.0000  0.0729  0.1155
# Checkin_2019-11-15            -0.1225   0.0134  -9.1341 0.0000 -0.1488 -0.0962
# Checkin_2019-11-18             0.0317   0.0104   3.0605 0.0022  0.0114  0.0520
# Checkin_2019-11-20             0.0702   0.0108   6.5238 0.0000  0.0491  0.0912
# Checkin_2019-11-22            -0.1838   0.0140 -13.0998 0.0000 -0.2113 -0.1563
# Checkin_2019-11-25            -0.0369   0.0104  -3.5561 0.0004 -0.0573 -0.0166
# Checkin_2019-11-27             0.0721   0.0118   6.1239 0.0000  0.0490  0.0951
# Checkin_2019-11-29            -0.1449   0.0138 -10.4838 0.0000 -0.1720 -0.1178
# Checkin_2019-12-02             0.1033   0.0119   8.7041 0.0000  0.0800  0.1265
# Checkin_2019-12-04             0.1672   0.0110  15.2550 0.0000  0.1457  0.1887
# Checkin_2019-12-06            -0.1154   0.0136  -8.4810 0.0000 -0.1420 -0.0887
# Checkin_2019-12-09             0.0615   0.0104   5.9109 0.0000  0.0411  0.0819
# Checkin_2019-12-11             0.0696   0.0109   6.3848 0.0000  0.0482  0.0909
# Checkin_2019-12-13            -0.1895   0.0134 -14.1398 0.0000 -0.2157 -0.1632
# Checkin_2019-12-16            -0.0360   0.0105  -3.4416 0.0006 -0.0565 -0.0155
# Checkin_2019-12-18            -0.0061   0.0107  -0.5754 0.5650 -0.0271  0.0148
# Checkin_2019-12-20            -0.2686   0.0133 -20.1492 0.0000 -0.2947 -0.2425
# Checkin_2019-12-23            -0.0170   0.0105  -1.6196 0.1053 -0.0377  0.0036
# Checkin_2019-12-25             0.0352   0.0108   3.2670 0.0011  0.0141  0.0563
# Checkin_2019-12-27            -0.1251   0.0137  -9.1247 0.0000 -0.1520 -0.0982
# Checkin_2019-12-30             0.5445   0.0110  49.4985 0.0000  0.5229  0.5660
# Checkin_2020-01-03            -0.2236   0.0134 -16.6574 0.0000 -0.2499 -0.1973
# Checkin_2020-01-06             0.6292   0.0117  53.7952 0.0000  0.6063  0.6521
# Checkin_2020-01-08             0.6838   0.0120  57.1878 0.0000  0.6603  0.7072
# Checkin_2020-01-10            -0.0819   0.0141  -5.8283 0.0000 -0.1095 -0.0544
# Checkout_2019-11-06            0.3898   0.0116  33.7403 0.0000  0.3672  0.4125
# Checkout_2019-11-08            0.5168   0.0117  44.1144 0.0000  0.4938  0.5398
# Checkout_2019-11-10            0.0045   0.0136   0.3275 0.7433 -0.0223  0.0312
# Checkout_2019-11-13            0.0542   0.0105   5.1676 0.0000  0.0336  0.0747
# Checkout_2019-11-15            0.0942   0.0109   8.6683 0.0000  0.0729  0.1155
# Checkout_2019-11-17           -0.1225   0.0134  -9.1341 0.0000 -0.1488 -0.0962
# Checkout_2019-11-20            0.0317   0.0104   3.0605 0.0022  0.0114  0.0520
# Checkout_2019-11-22            0.0702   0.0108   6.5238 0.0000  0.0491  0.0912
# Checkout_2019-11-24           -0.1838   0.0140 -13.0998 0.0000 -0.2113 -0.1563
# Checkout_2019-11-27           -0.0369   0.0104  -3.5561 0.0004 -0.0573 -0.0166
# Checkout_2019-11-29            0.0721   0.0118   6.1239 0.0000  0.0490  0.0951
# Checkout_2019-12-01           -0.1449   0.0138 -10.4838 0.0000 -0.1720 -0.1178
# Checkout_2019-12-04            0.1033   0.0119   8.7041 0.0000  0.0800  0.1265
# Checkout_2019-12-06            0.1672   0.0110  15.2550 0.0000  0.1457  0.1887
# Checkout_2019-12-08           -0.1154   0.0136  -8.4810 0.0000 -0.1420 -0.0887
# Checkout_2019-12-11            0.0615   0.0104   5.9109 0.0000  0.0411  0.0819
# Checkout_2019-12-13            0.0696   0.0109   6.3848 0.0000  0.0482  0.0909
# Checkout_2019-12-15           -0.1895   0.0134 -14.1398 0.0000 -0.2157 -0.1632
# Checkout_2019-12-18           -0.0360   0.0105  -3.4416 0.0006 -0.0565 -0.0155
# Checkout_2019-12-20           -0.0061   0.0107  -0.5754 0.5650 -0.0271  0.0148
# Checkout_2019-12-22           -0.2686   0.0133 -20.1492 0.0000 -0.2947 -0.2425
# Checkout_2019-12-25           -0.0170   0.0105  -1.6196 0.1053 -0.0377  0.0036
# Checkout_2019-12-27            0.0352   0.0108   3.2670 0.0011  0.0141  0.0563
# Checkout_2019-12-29           -0.1251   0.0137  -9.1247 0.0000 -0.1520 -0.0982
# Checkout_2020-01-01            0.5445   0.0110  49.4985 0.0000  0.5229  0.5660
# Checkout_2020-01-05           -0.2236   0.0134 -16.6574 0.0000 -0.2499 -0.1973
# Checkout_2020-01-08            0.6292   0.0117  53.7952 0.0000  0.6063  0.6521
# Checkout_2020-01-10            0.6838   0.0120  57.1878 0.0000  0.6603  0.7072
# Checkout_2020-01-12           -0.0819   0.0141  -5.8283 0.0000 -0.1095 -0.0544
# zip_code_89012                 0.4700   0.0640   7.3457 0.0000  0.3446  0.5954
# zip_code_89014                 0.0557   0.0650   0.8579 0.3909 -0.0716  0.1831
# zip_code_89030                 0.0636   0.0670   0.9498 0.3422 -0.0677  0.1949
# zip_code_89032                -0.2589   0.0942  -2.7488 0.0060 -0.4436 -0.0743
# zip_code_89052                 0.2069   0.0592   3.4934 0.0005  0.0908  0.3230
# zip_code_89081                 0.1148   0.0628   1.8272 0.0677 -0.0083  0.2379
# zip_code_89101                -0.1769   0.0898  -1.9693 0.0489 -0.3529 -0.0008
# zip_code_89102                -0.1196   0.0923  -1.2952 0.1953 -0.3005  0.0614
# zip_code_89103                -0.1205   0.0905  -1.3312 0.1831 -0.2980  0.0569
# zip_code_89104                -0.2919   0.0912  -3.2010 0.0014 -0.4706 -0.1132
# zip_code_89105                -0.2584   0.1079  -2.3938 0.0167 -0.4699 -0.0468
# zip_code_89107                -0.3638   0.0991  -3.6694 0.0002 -0.5581 -0.1694
# zip_code_89108                 0.1215   0.0878   1.3844 0.1663 -0.0505  0.2936
# zip_code_89109                 0.0411   0.0891   0.4615 0.6444 -0.1335  0.2157
# zip_code_89117                 0.1127   0.0751   1.5009 0.1334 -0.0345  0.2599
# zip_code_89118                -0.1395   0.0893  -1.5635 0.1180 -0.3145  0.0354
# zip_code_89119                -0.0854   0.0876  -0.9742 0.3300 -0.2572  0.0864
# zip_code_89121                -0.3223   0.0883  -3.6520 0.0003 -0.4954 -0.1493
# zip_code_89122                -0.0273   0.0820  -0.3329 0.7392 -0.1881  0.1335
# zip_code_89123                -0.1051   0.0835  -1.2590 0.2080 -0.2688  0.0586
# zip_code_89128                 0.0255   0.0712   0.3573 0.7209 -0.1142  0.1651
# zip_code_89130                -0.3607   0.0924  -3.9048 0.0001 -0.5418 -0.1796
# zip_code_89135                 0.3635   0.0748   4.8569 0.0000  0.2168  0.5102
# zip_code_89139                -0.3061   0.0813  -3.7642 0.0002 -0.4655 -0.1467
# zip_code_89144                 0.1291   0.0784   1.6467 0.0996 -0.0246  0.2827
# zip_code_89145                -0.0431   0.0790  -0.5453 0.5855 -0.1980  0.1118
# zip_code_89147                -0.0997   0.0705  -1.4140 0.1574 -0.2379  0.0385
# zip_code_89158                 0.9425   0.0950   9.9224 0.0000  0.7563  1.1287
# zip_code_89169                -0.0268   0.0883  -0.3034 0.7616 -0.1999  0.1463
# zip_code_89183                 0.2489   0.0711   3.5017 0.0005  0.1096  0.3882
# hotel_rating_Fabulous         -0.0514   0.0245  -2.1018 0.0356 -0.0994 -0.0035
# hotel_rating_Good             -0.1778   0.0330  -5.3861 0.0000 -0.2425 -0.1131
# hotel_rating_No Rating         0.4791   0.0452  10.5942 0.0000  0.3905  0.5677
# hotel_rating_Superb            0.0427   0.0240   1.7800 0.0751 -0.0043  0.0897
# hotel_rating_Very Good        -0.1498   0.0269  -5.5771 0.0000 -0.2024 -0.0971
# Checkin_Day_Monday             1.7242   0.0560  30.7978 0.0000  1.6145  1.8340
# Checkin_Day_Wednesday          1.7029   0.0554  30.7526 0.0000  1.5943  1.8114
# Checkout_Day_Sunday            2.1034   0.0624  33.7239 0.0000  1.9811  2.2257
# Checkout_Day_Wednesday         1.7242   0.0560  30.7978 0.0000  1.6145  1.8340
# When_in_Week_End of Week       1.7029   0.0554  30.7526 0.0000  1.5943  1.8114
# When_in_Week_Weekend           2.1034   0.0624  33.7239 0.0000  1.9811  2.2257
# log_hotel_num_guest_reviews   -0.1378   0.0035 -39.0070 0.0000 -0.1448 -0.1309
# log_num_ta_reviews             0.0569   0.0040  14.2730 0.0000  0.0491  0.0647
# ------------------------------------------------------------------------------
# Omnibus:              1799.980       Durbin-Watson:          1.783
# Prob(Omnibus):        0.000          Jarque-Bera (JB):       5183.485
# Skew:                 0.616          Prob(JB):               0.000
# Kurtosis:             5.512          Condition No.:          14955133435484832
# ==============================================================================
# * The condition number is large (1e+16). This might indicate
# strong multicollinearity or other numerical problems.
# """

# %%
plt.figure(figsize = (10,8));
plt.scatter(fit_model2.predict(), fit_model2.resid);

# %% [markdown]
# #### Model Evaluation Metric
#
# We will be using the Root Mean Squared Error:

# %%
def MAE(y_true, y_pred):
    return np.mean(abs(y_true - y_pred))

# %%
def RMSE(y_true, y_pred):
    return (np.mean((y_true - y_pred)**2))**0.5

# %% [markdown]
# #### Train/Test Split

# %%
X = sub_hotel_df_dummies2.drop(['sales_price', 
                                'log_price', 
                                'hotel_num_guest_reviews',
                                'num_ta_reviews'], 1)
y = sub_hotel_df_dummies2.log_price

# 60 - 20 - 20 (Train/Val/Test Split)
X, X_test, y, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state= 42)

# %% [markdown]
# #### Simple Linear Regression

# %%
lm = LinearRegression()

lm.fit(X_train, y_train)

y_prediction = lm.predict(X_val)
print(f'The simple Linear Regression R-Square is: {r2_score(y_val, y_prediction)}')
print(MAE(np.exp(y_val), np.exp(y_prediction)), RMSE(np.exp(y_val), np.exp(y_prediction)))
# Out:
# The simple Linear Regression R-Square is: 0.615617479393975
# 66.30779784721416 201.7214493106822

# %% [markdown]
# Based on the high RMSE, we can tell that the model is heavily influenced by outliers. RMSE punishes oberservations with high target values.
#
# * We can further filter our target value further to exclude outliers

# %%
# We find a set of data which only consist of hotel prices below the max value
max_price = find_feature_limit(sub_hotel_df_dummies2, 'sales_price')[1]
hotel_price_filter = sub_hotel_df_dummies2[sub_hotel_df_dummies2.sales_price < max_price]

# %%
X = hotel_price_filter.drop(['sales_price', 
                                'log_price', 
                                'hotel_num_guest_reviews',
                                'num_ta_reviews'], 1)
y = hotel_price_filter.log_price

# 60 - 20 - 20 (Train/Val/Test Split)
X, X_test, y, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state= 42)

# %%
lm = LinearRegression()

lm.fit(X_train, y_train)

y_prediction = lm.predict(X_val)
print(f'The simple Linear Regression R-Square is: {r2_score(y_val, y_prediction)}')
print(MAE(np.exp(y_val), np.exp(y_prediction)), RMSE(np.exp(y_val), np.exp(y_prediction)))
# Out:
# The simple Linear Regression R-Square is: 0.5951821606623686
# 33.77101523586923 47.037187822484356

# %%
plt.figure(figsize = (10,8));
plt.scatter(lm.predict(X_val), y_val - y_prediction);
np.mean(y_val - y_prediction)
# Out:
# -0.005482724239562634

# %% [markdown]
# ### Model Selection

# %% [markdown]
# We will train the model with simple linear regression, Regression with Lasso, Regression with Ridge:
#
# 1. We will train data with all 3 models and calculate R-squared and RMSE/or MAE as our performance metric
# 2. We will then remove all the features with zero beta coefficients based on Lasso and create a new set of non-zero beta coefficient features
# 3. We will optimize the beta values by feeding the set of new features into Ridge
# 4. We can also feed the new set of features into simple Linear Regression
# 5. We can use ElasticNet or SGDRegressor to see if model gives better performance
# 6. Lastly, we can use GridSearch to find our hyperparameter for each of these estimators and test the model performance.
#
# We will choose the model with the lowest RMSE on the test set

# %%
X = hotel_price_filter.drop(['sales_price', 'log_price', 'hotel_num_guest_reviews', 'num_ta_reviews'], 1)
y = hotel_price_filter.log_price

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# #### Simple Linear Regression

# %%
def lm_cv(X, y):
    
    lm = LinearRegression()
    lm.fit(X, y)  
    y_prediction = lm.predict(X)
    print(f'The Simple Regression R-Squared is {lm.score(X, y)}')
    
    kf = KFold(n_splits=5, shuffle=True, random_state = 101)
    R_Squared = np.mean(cross_val_score(lm, X_val, y_val, cv=kf, scoring='r2'))
    print(f'The R-squared using CV is {R_Squared}')
    MAE = MAE(np.exp(y), np.exp(y_prediction))
    RMSE = RMSE(np.exp(y), np.exp(y_prediction))
    print(f'The MAE is {MAE} and RMSE is {RMSE}')
    coef_list = list(zip(X_train.columns, lm.coef_))
    return (sorted(coef_list, key = lambda tuple: tuple[1], reverse = True), 
            R_Squared, MAE, RMSE)

# %% [markdown]
# #### LassoCV

# %%
def lasso_cv(X, y, alphavec, cv = 5):
    
    # Scalar Transformation
    std = StandardScaler()
    std.fit(X.values)
    X_train_scaled = std.transform(X.values)
    # Search the alpha vector and find the best alpha
    model_lassoCV = LassoCV(alphas = alphavec, cv = cv, max_iter = 10000)
    model_lassoCV.fit(X_train_scaled, y)
    y_prediction = model_lassoCV.predict(X_train_scaled)
    
    print(f'The optimal alpha is {model_lassoCV.alpha_}')
    print(f'The R-Squared is {model_lassoCV.score(X_train_scaled, y)}')
    
    kf = KFold(n_splits = 5, shuffle = True, random_state = 101)
    R_Squared = np.mean(cross_val_score(model_lassoCV, X_train_scaled, y, cv = kf, scoring = 'r2'))
    print(f'The R-Squared value using CV is: {R_Squared}')
    MAE = MAE(np.exp(y), np.exp(y_prediction))
    RMSE = RMSE(np.exp(y), np.exp(y_prediction))
    print(f'The MAE is {MAE} and RMSE is {RMSE}')
    coef_list = list(zip(X.columns, model_lassoCV.coef_))
    return (sorted(coef_list, key = lambda tuple: tuple[1], reverse = True), 
            R_Squared, MAE, RMSE)

# %% [markdown]
# #### RidgeCV

# %%
def ridge_cv(X, y, alphavec, cv = 5):
    
    # Scalar Transformation
    std = StandardScaler()
    std.fit(X.values)
    X_train_scaled = std.transform(X.values)
    # Search the alpha vector and find the best alpha
    model_RidgeCV = RidgeCV(alphas = alphavec, cv = cv)
    model_RidgeCV.fit(X_train_scaled, y)
    y_prediction = model_RidgeCV.predict(X_train_scaled)
    
    print(f'The optimal alpha is {model_RidgeCV.alpha_}')
    print(f'The RidgeCV Regression R-Squared is {model_RidgeCV.score(X_train_scaled, y)}')
    
    kf = KFold(n_splits=5, shuffle=True, random_state = 101)
    R_Squared = np.mean(cross_val_score(model_RidgeCV, X_train_scaled, y, cv=kf, scoring='r2'))
    print(f'The R_Squared using CV is {R_Squared}')
    MAE = MAE(np.exp(y), np.exp(y_prediction))
    RMSE = RMSE(np.exp(y), np.exp(y_prediction))
    print(f'The MAE is {MAE} and RMSE is {RMSE}')
    coef_list = list(zip(X.columns, model_RidgeCV.coef_))
    return (sorted(coef_list, key = lambda tuple: tuple[1], reverse = True), 
            R_Squared, MAE, RMSE)

# %% [markdown]
# #### ElasticNetCV

# %%
def ElasticNCV(X, y, alphavec, cv = 5):
    
    # Standard Scale our X features:
    std = StandardScaler()
    std.fit(X.values)
    X_train_scaled = std.transform(X.values)
    
    # Use ElasticNetCV to search for a range of alpha values setting l1_Ratio = 0.1
    model_ElasticNetCV = ElasticNetCV(alphas = alphavec, l1_ratio = 0.1, cv = cv, max_iter = 10000)
    model_ElasticNetCV.fit(X_train_scaled, y)
    y_prediction = model_ElasticNetCV.predict(X_train_scaled)
    
    print(f'The optimal alpha is {model_ElasticNetCV.alpha_}')
    print(f'The ElasticNetCV Regression R-Squared is: {model_ElasticNetCV.score(X_train_scaled, y)}')

    kf = KFold(n_splits = 5, shuffle = True, random_state = 101)
    R_Squared = np.mean(cross_val_score(model_ElasticNetCV, X_train_scaled, y, cv = kf, scoring = 'r2'))
    print(f'The R-Squared using CV is {R_Squared}')
    MAE = MAE(np.exp(y), np.exp(y_prediction))
    RMSE = RMSE(np.exp(y), np.exp(y_prediction))
    print(f'The MAE is {MAE} and RMSE is {RMSE}')
    coef_list = list(zip(X.columns, model_ElasticNetCV.coef_))
    return (sorted(coef_list, key = lambda tuple: tuple[1], reverse = True), 
            R_Squared, MAE, RMSE)

# %% [markdown]
# #### Simple Regression

# %%
lm_coef = lm_cv(X_train, y_train)
# Out:
# The Simple Regression R-Squared is 0.6129472907978861
# The R-squared using CV is 0.5841076204490706
# The MAE is 33.218933123483026 and RMSE is 46.54978453086772

# %% [markdown]
# #### LassoCV

# %%
alphavec = 10 * np.linspace(-0.01,0.01,200)
lasso_coef = lasso_cv(X_train, y_train, alphavec)
# Out:
# The optimal alpha is 0.0005025125628140698
# The R-Squared is 0.6124689255727637
# The R-Squared value using CV is: 0.6059513274392688
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-328-5e4426e0ccac> in <module>()
#       1 alphavec = 10 * np.linspace(-0.01,0.01,200)
# ----> 2 lasso_coef = lasso_cv(X_train, y_train, alphavec)
#
# <ipython-input-323-9fbe2e3ca713> in lasso_cv(X, y, alphavec, cv)
#      16     R_Squared = np.mean(cross_val_score(model_lassoCV, X_train_scaled, y, cv = kf, scoring = 'r2'))
#      17     print(f'The R-Squared value using CV is: {R_Squared}')
# ---> 18     MAE = MAE(np.exp(y), np.exp(y_prediction))
#      19     RMSE = RMSE(np.exp(y), np.exp(y_prediction))
#      20     print(f'The MAE is {MAE} and RMSE is {RMSE}')
#
# UnboundLocalError: local variable 'MAE' referenced before assignment

# %% [markdown]
# #### RidgeCV

# %%
alphavec = 10 * np.linspace(-2,2,200)
ridge_coef = ridge_cv(X_train, y_train, alphavec)
# Out:
# The optimal alpha is 13.969849246231156
# The RidgeCV Regression R-Squared is 0.6129350579606826
# The R_Squared using CV is 0.6063441495755351
# The MAE is 33.20349582077205 and the RMSE is 46.52360325659541

# %% [markdown]
# #### ElasticNetCV

# %%
alphavec = 10**np.linspace(-3,3,200)
Elastic_coef = ElasticNCV(X_train, y_train, alphavec)
# Out:
# The optimal alpha is 0.001
# The ElasticNetCV Regression R-Squared is: 0.6128975613542216
# The R-Squared using CV is 0.6063504184991583
# The MAE is 33.18043307755614 and RMSE is 46.490677481002905

# %% [markdown]
# #### Let's train RidgeCV and ElasticNetCV again with only non-zeroed features

# %% [markdown]
# #### We need to find the features with zeroed coef_ determined by the lasso model
#
# * We can feed these non-zero features into RidgeCV, ElasticNetCV to better improve our model

# %%
non_zero_coef = [coef for coef in lasso_coef[:][0] if abs(coef[1] == 0)]
zero_coef_features = [element[0] for element in non_zero_coef]
zero_coef_features
# Out:
# ['airport_transfer',
#  'Checkin_2019-11-11',
#  'Checkout_2019-12-27',
#  'Checkout_2019-12-29',
#  'zip_code_89169',
#  'Checkin_Day_Monday',
#  'Checkin_Day_Wednesday',
#  'Checkout_Day_Wednesday',
#  'When_in_Week_End of Week']

# %%
zero_coef_features.extend(['sales_price', 'log_price', 'hotel_num_guest_reviews', 'num_ta_reviews'])
X_NZ = hotel_price_filter.drop(zero_coef_features ,axis = 1)
y_NZ = hotel_price_filter['log_price']
    
X_train_NZ, X_test_NZ, y_train_NZ, y_test_NZ = train_test_split(X_NZ, y_NZ, test_size=0.20, random_state=42)

# %%
alphavec = 10 * np.linspace(-2,2,200)
ridge_NZ_coef = ridge_cv(X_train_NZ, y_train_NZ, alphavec)
# Out:
# The optimal alpha is 9.145728643216081
# The RidgeCV Regression R-Squared is 0.6129158716355272
# The R_Squared using CV is 0.6063317229444176
# The MAE is 33.20199824254924 and the RMSE is 46.52817743437963

# %%
alphavec = 10**np.linspace(-3,3,200)
Elastic_NZ_coef = ElasticNCV(X_train_NZ, y_train_NZ, alphavec)
# Out:
# The optimal alpha is 0.001
# The ElasticNetCV Regression R-Squared is: 0.6128748098864952
# The R-Squared using CV is 0.6063518332480062
# The MAE is 33.17634488268808 and RMSE is 46.488853521890626

# %% [markdown]
# ##### Let's try simple LinearRegression CV with only non-zero coef features determined by Lasso

# %%
lm_coef_NZ = lm_cv(X_train_NZ, y_train_NZ)
# Out:
# The Simple Regression R-Squared is 0.6129223149909169
# The R-squared using CV is 0.5841076204490706
# The MAE is 33.21253404516432 and RMSE is 46.546995370175104

# %% [markdown]
# #### Create a DataFrame reporting all the model performance

# %% [markdown]
# #### The best model based on both R-Squared and error is using LassoCV

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.datasets import load_digits
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit


def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 10)):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : int or None, optional (default=None)
        Number of jobs to run in parallel.
        ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.
        ``-1`` means using all processors. See :term:`Glossary <n_jobs>`
        for more details.

    train_sizes : array-like, shape (n_ticks,), dtype float or int
        Relative or absolute numbers of training examples that will be used to
        generate the learning curve. If the dtype is float, it is regarded as a
        fraction of the maximum size of the training set (that is determined
        by the selected validation method), i.e. it has to be within (0, 1].
        Otherwise it is interpreted as absolute sizes of the training sets.
        Note that for classification the number of samples usually have to
        be big enough to contain at least one sample from each class.
        (default: np.linspace(0.1, 1.0, 5))
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt
# Out:
# Automatically created module for IPython interactive environment

# %%
import warnings
warnings.filterwarnings(action='ignore')
alphavec = 10**np.linspace(-3,3,200)
plot_learning_curve(ElasticNetCV(alphas = alphavec, l1_ratio = 0.1, max_iter = 10000), 'Learning Rate of ElasticNetCV Model', X_train, y_train);

# %% [markdown]
# The learning curve tells us that the cross validation and training score is close. My model is not suffering from bias or variance. With current features, the max score converges to about ~0.62.
#
# For further improvement, we need to add more features or train a most complex model. First we will try to add more features using polynomial features

# %%
num_columns = ['Adults', 'Children', 'distance_city_center',
       'distance_convention_center',
       'hotel_reviews', 'hotel_num_guest_reviews', 'num_ta_reviews',
       'ta_reviews']

other_columns = ['Checkin', 'Checkout', 'zip_code', 'hotel_rating',
              'Checkin_Day', 'Checkout_Day', 'sales_price',
               'When_in_Week', 'parking', 'pool', 'gym', 'air_conditioning',
               'pet_friendly', 'kitchen', 'airport_transfer']

hotel_num_df = hotel_df[num_columns]
hotel_num_df2 = hotel_num_df.copy()
hotel_num_df2['log_hotel_num_reviews'] = np.log(hotel_num_df2['hotel_num_guest_reviews'])
hotel_num_df2['log_num_ta_reviews'] = np.log(hotel_num_df2['num_ta_reviews'])
drop_col = ['hotel_num_guest_reviews', 'num_ta_reviews']
hotel_cat_df = hotel_df[cat_columns]
hotel_cat_df.reset_index(drop = True, inplace = True)

from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(2)
X_poly = poly.fit_transform(hotel_num_df2.drop(drop_col, 1))
X_poly_df = pd.DataFrame(data=X_poly,
                         index=np.arange(0,len(X_poly)),
                         columns=np.arange(1,46))

hotel_poly_df = hotel_cat_df.join(X_poly_df)

# %%
hotel_poly_df2 = hotel_poly_df.copy()
hotel_poly_df2 = pd.get_dummies(hotel_poly_df2, drop_first = True)
# sub_hotel_df_dummies2['log_distances'] = np.log(sub_hotel_df_FE.distance_city_convention)
# hotel_poly_df2['log_hotel_num_guest_reviews'] = np.log(hotel_poly_df2.hotel_num_guest_reviews)
# hotel_poly_df2['log_num_ta_reviews'] = np.log(hotel_poly_df2.num_ta_reviews)
hotel_poly_df2['log_price'] = np.log(hotel_poly_df2.sales_price)

# %%
X = hotel_poly_df2.drop(['sales_price', 'log_price'], 1)
y = hotel_poly_df2.log_price

# 60 - 20 - 20 (Train/Val/Test Split)
X, X_test, y, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state= 42)

# %% [markdown]
# #### Stats Model with polynomial features

# %%
statsmodel_poly = sm.OLS(y,X)
fit_model_poly = statsmodel_poly.fit()
fit_model_poly.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_price   R-squared:                       0.662
# Model:                            OLS   Adj. R-squared:                  0.659
# Method:                 Least Squares   F-statistic:                     220.4
# Date:                Tue, 08 Oct 2019   Prob (F-statistic):               0.00
# Time:                        22:44:14   Log-Likelihood:                -6663.4
# No. Observations:               12717   AIC:                         1.355e+04
# Df Residuals:                   12604   BIC:                         1.439e+04
# Df Model:                         112
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# parking                     -0.0898      0.026     -3.494      0.000      -0.140      -0.039
# pool                        -0.1812      0.019     -9.675      0.000      -0.218      -0.144
# gym                          0.0878      0.015      5.672      0.000       0.057       0.118
# air_conditioning             0.2398      0.029      8.399      0.000       0.184       0.296
# pet_friendly                 0.0106      0.013      0.830      0.407      -0.014       0.035
# kitchen                     -0.1386      0.012    -11.281      0.000      -0.163      -0.114
# airport_transfer            -0.0157      0.014     -1.110      0.267      -0.043       0.012
# 1                            1.4705      0.119     12.311      0.000       1.236       1.705
# 2                            1.9097      0.155     12.336      0.000       1.606       2.213
# 3                            0.0158      0.005      3.313      0.001       0.006       0.025
# 4                            0.3037      0.043      7.076      0.000       0.220       0.388
# 5                           -0.2493      0.051     -4.875      0.000      -0.350      -0.149
# 6                           -1.1207      0.123     -9.089      0.000      -1.362      -0.879
# 7                            0.9329      0.138      6.772      0.000       0.663       1.203
# 8                            0.4934      0.044     11.227      0.000       0.407       0.580
# 9                           -0.5175      0.047    -10.933      0.000      -0.610      -0.425
# 10                          -0.3053      0.028    -11.069      0.000      -0.359      -0.251
# 11                           0.0316      0.010      3.313      0.001       0.013       0.050
# 12                          -0.0009      0.004     -0.208      0.835      -0.009       0.008
# 13                          -0.0038      0.005     -0.825      0.409      -0.013       0.005
# 14                          -0.0058      0.007     -0.791      0.429      -0.020       0.009
# 15                          -0.0055      0.014     -0.393      0.694      -0.033       0.022
# 16                           0.0187      0.004      4.857      0.000       0.011       0.026
# 17                          -0.0028      0.004     -0.713      0.476      -0.011       0.005
# 18                           0.0316      0.010      3.313      0.001       0.013       0.050
# 19                          -0.0092      0.004     -2.133      0.033      -0.018      -0.001
# 20                           0.0003      0.005      0.060      0.952      -0.009       0.009
# 21                          -0.0082      0.007     -1.111      0.266      -0.023       0.006
# 22                           0.0003      0.014      0.023      0.981      -0.026       0.027
# 23                           0.0058      0.004      1.504      0.133      -0.002       0.013
# 24                          -0.0037      0.004     -0.945      0.344      -0.011       0.004
# 25                           0.0789      0.009      8.755      0.000       0.061       0.097
# 26                          -0.1205      0.016     -7.634      0.000      -0.151      -0.090
# 27                          -0.0023      0.008     -0.290      0.772      -0.018       0.013
# 28                          -0.0579      0.015     -3.912      0.000      -0.087      -0.029
# 29                          -0.0542      0.005    -10.796      0.000      -0.064      -0.044
# 30                           0.0298      0.005      5.790      0.000       0.020       0.040
# 31                           0.0554      0.008      7.087      0.000       0.040       0.071
# 32                           0.0242      0.009      2.794      0.005       0.007       0.041
# 33                           0.0001      0.016      0.008      0.993      -0.032       0.032
# 34                           0.0353      0.005      6.728      0.000       0.025       0.046
# 35                          -0.0277      0.006     -5.021      0.000      -0.039      -0.017
# 36                           0.1181      0.010     11.258      0.000       0.097       0.139
# 37                          -0.1009      0.021     -4.730      0.000      -0.143      -0.059
# 38                           0.1048      0.004     25.247      0.000       0.097       0.113
# 39                          -0.1028      0.006    -16.533      0.000      -0.115      -0.091
# 40                           0.0155      0.023      0.659      0.510      -0.031       0.061
# 41                          -0.3285      0.011    -29.880      0.000      -0.350      -0.307
# 42                           0.3017      0.013     22.844      0.000       0.276       0.328
# 43                          -0.0112      0.002     -6.171      0.000      -0.015      -0.008
# 44                          -0.0118      0.004     -3.324      0.001      -0.019      -0.005
# 45                           0.0246      0.003      9.302      0.000       0.019       0.030
# Checkin_2019-11-04           0.2528      0.011     22.775      0.000       0.231       0.275
# Checkin_2019-11-06           0.3698      0.011     33.189      0.000       0.348       0.392
# Checkin_2019-11-08           0.0030      0.014      0.210      0.834      -0.025       0.031
# Checkin_2019-11-11          -0.0800      0.010     -7.938      0.000      -0.100      -0.060
# Checkin_2019-11-13          -0.0427      0.010     -4.188      0.000      -0.063      -0.023
# Checkin_2019-11-15          -0.1151      0.014     -8.161      0.000      -0.143      -0.087
# Checkin_2019-11-18          -0.1044      0.010    -10.620      0.000      -0.124      -0.085
# Checkin_2019-11-20          -0.0702      0.010     -6.989      0.000      -0.090      -0.050
# Checkin_2019-11-22          -0.1832      0.015    -12.361      0.000      -0.212      -0.154
# Checkin_2019-11-25          -0.1579      0.010    -16.239      0.000      -0.177      -0.139
# Checkin_2019-11-27          -0.0807      0.011     -7.318      0.000      -0.102      -0.059
# Checkin_2019-11-29          -0.1442      0.014     -9.989      0.000      -0.173      -0.116
# Checkin_2019-12-02          -0.0329      0.011     -2.887      0.004      -0.055      -0.011
# Checkin_2019-12-04           0.0282      0.010      2.728      0.006       0.008       0.048
# Checkin_2019-12-06          -0.1080      0.014     -7.539      0.000      -0.136      -0.080
# Checkin_2019-12-09          -0.0666      0.010     -6.801      0.000      -0.086      -0.047
# Checkin_2019-12-11          -0.0750      0.010     -7.363      0.000      -0.095      -0.055
# Checkin_2019-12-13          -0.1779      0.014    -12.553      0.000      -0.206      -0.150
# Checkin_2019-12-16          -0.1642      0.010    -16.531      0.000      -0.184      -0.145
# Checkin_2019-12-18          -0.1463      0.010    -14.752      0.000      -0.166      -0.127
# Checkin_2019-12-20          -0.2639      0.014    -18.693      0.000      -0.292      -0.236
# Checkin_2019-12-23          -0.1483      0.010    -15.010      0.000      -0.168      -0.129
# Checkin_2019-12-25          -0.1124      0.010    -10.979      0.000      -0.132      -0.092
# Checkin_2019-12-27          -0.1257      0.014     -8.701      0.000      -0.154      -0.097
# Checkin_2019-12-30           0.4131      0.011     38.606      0.000       0.392       0.434
# Checkin_2020-01-03          -0.2286      0.014    -16.198      0.000      -0.256      -0.201
# Checkin_2020-01-06           0.5001      0.011     44.938      0.000       0.478       0.522
# Checkin_2020-01-08           0.5307      0.012     45.496      0.000       0.508       0.554
# Checkin_2020-01-10          -0.0864      0.015     -5.912      0.000      -0.115      -0.058
# Checkout_2019-11-06          0.2528      0.011     22.775      0.000       0.231       0.275
# Checkout_2019-11-08          0.3698      0.011     33.189      0.000       0.348       0.392
# Checkout_2019-11-10          0.0030      0.014      0.210      0.834      -0.025       0.031
# Checkout_2019-11-13         -0.0800      0.010     -7.938      0.000      -0.100      -0.060
# Checkout_2019-11-15         -0.0427      0.010     -4.188      0.000      -0.063      -0.023
# Checkout_2019-11-17         -0.1151      0.014     -8.161      0.000      -0.143      -0.087
# Checkout_2019-11-20         -0.1044      0.010    -10.620      0.000      -0.124      -0.085
# Checkout_2019-11-22         -0.0702      0.010     -6.989      0.000      -0.090      -0.050
# Checkout_2019-11-24         -0.1832      0.015    -12.361      0.000      -0.212      -0.154
# Checkout_2019-11-27         -0.1579      0.010    -16.239      0.000      -0.177      -0.139
# Checkout_2019-11-29         -0.0807      0.011     -7.318      0.000      -0.102      -0.059
# Checkout_2019-12-01         -0.1442      0.014     -9.989      0.000      -0.173      -0.116
# Checkout_2019-12-04         -0.0329      0.011     -2.887      0.004      -0.055      -0.011
# Checkout_2019-12-06          0.0282      0.010      2.728      0.006       0.008       0.048
# Checkout_2019-12-08         -0.1080      0.014     -7.539      0.000      -0.136      -0.080
# Checkout_2019-12-11         -0.0666      0.010     -6.801      0.000      -0.086      -0.047
# Checkout_2019-12-13         -0.0750      0.010     -7.363      0.000      -0.095      -0.055
# Checkout_2019-12-15         -0.1779      0.014    -12.553      0.000      -0.206      -0.150
# Checkout_2019-12-18         -0.1642      0.010    -16.531      0.000      -0.184      -0.145
# Checkout_2019-12-20         -0.1463      0.010    -14.752      0.000      -0.166      -0.127
# Checkout_2019-12-22         -0.2639      0.014    -18.693      0.000      -0.292      -0.236
# Checkout_2019-12-25         -0.1483      0.010    -15.010      0.000      -0.168      -0.129
# Checkout_2019-12-27         -0.1124      0.010    -10.979      0.000      -0.132      -0.092
# Checkout_2019-12-29         -0.1257      0.014     -8.701      0.000      -0.154      -0.097
# Checkout_2020-01-01          0.4131      0.011     38.606      0.000       0.392       0.434
# Checkout_2020-01-05         -0.2286      0.014    -16.198      0.000      -0.256      -0.201
# Checkout_2020-01-08          0.5001      0.011     44.938      0.000       0.478       0.522
# Checkout_2020-01-10          0.5307      0.012     45.496      0.000       0.508       0.554
# Checkout_2020-01-12         -0.0864      0.015     -5.912      0.000      -0.115      -0.058
# zip_code_89012               0.3240      0.085      3.805      0.000       0.157       0.491
# zip_code_89014               0.3609      0.082      4.414      0.000       0.201       0.521
# zip_code_89030              -0.3033      0.092     -3.300      0.001      -0.483      -0.123
# zip_code_89032               0.2174      0.108      2.009      0.045       0.005       0.430
# zip_code_89052               0.5796      0.102      5.687      0.000       0.380       0.779
# zip_code_89081              -0.3471      0.090     -3.848      0.000      -0.524      -0.170
# zip_code_89101               0.4015      0.109      3.671      0.000       0.187       0.616
# zip_code_89102               0.6568      0.120      5.493      0.000       0.422       0.891
# zip_code_89103               0.5989      0.118      5.082      0.000       0.368       0.830
# zip_code_89104               0.1887      0.115      1.647      0.100      -0.036       0.413
# zip_code_89105               0.6353      0.129      4.914      0.000       0.382       0.889
# zip_code_89107               0.0807      0.118      0.686      0.493      -0.150       0.311
# zip_code_89108               0.5054      0.102      4.942      0.000       0.305       0.706
# zip_code_89109               0.6447      0.114      5.645      0.000       0.421       0.869
# zip_code_89117               0.7104      0.111      6.392      0.000       0.493       0.928
# zip_code_89118               0.5757      0.118      4.868      0.000       0.344       0.807
# zip_code_89119               0.6522      0.115      5.670      0.000       0.427       0.878
# zip_code_89121               0.1130      0.105      1.074      0.283      -0.093       0.319
# zip_code_89122               0.4160      0.095      4.362      0.000       0.229       0.603
# zip_code_89123               0.7584      0.118      6.438      0.000       0.527       0.989
# zip_code_89128               0.2852      0.088      3.234      0.001       0.112       0.458
# zip_code_89130              -0.2749      0.104     -2.650      0.008      -0.478      -0.072
# zip_code_89135               0.5904      0.122      4.843      0.000       0.351       0.829
# zip_code_89139               0.2803      0.115      2.428      0.015       0.054       0.507
# zip_code_89144               0.4288      0.114      3.772      0.000       0.206       0.652
# zip_code_89145               0.4434      0.103      4.295      0.000       0.241       0.646
# zip_code_89147               0.3752      0.120      3.130      0.002       0.140       0.610
# zip_code_89158               1.3707      0.120     11.427      0.000       1.136       1.606
# zip_code_89169               0.6098      0.115      5.306      0.000       0.385       0.835
# zip_code_89183               0.8289      0.125      6.619      0.000       0.583       1.074
# hotel_rating_Fabulous        0.2300      0.040      5.751      0.000       0.152       0.308
# hotel_rating_Good            0.4508      0.062      7.257      0.000       0.329       0.573
# hotel_rating_No Rating       0.9610      0.059     16.317      0.000       0.846       1.076
# hotel_rating_Superb          0.1813      0.032      5.590      0.000       0.118       0.245
# hotel_rating_Very Good       0.3465      0.050      6.893      0.000       0.248       0.445
# Checkin_Day_Monday           0.4116      0.039     10.594      0.000       0.335       0.488
# Checkin_Day_Wednesday        0.4015      0.038     10.438      0.000       0.326       0.477
# Checkout_Day_Sunday          0.6573      0.043     15.259      0.000       0.573       0.742
# Checkout_Day_Wednesday       0.4116      0.039     10.594      0.000       0.335       0.488
# When_in_Week_End of Week     0.4015      0.038     10.438      0.000       0.326       0.477
# When_in_Week_Weekend         0.6573      0.043     15.259      0.000       0.573       0.742
# ==============================================================================
# Omnibus:                     1077.639   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3884.809
# Skew:                           0.388   Prob(JB):                         0.00
# Kurtosis:                       5.594   Cond. No.                     1.16e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.75e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# #### Simple Linear Regression with polynomial features

# %%
lm_poly = LinearRegression()

lm_poly.fit(X_train, y_train)

y_prediction = lm_poly.predict(X_val)
print(f'The simple Linear Regression R-Square is: {r2_score(y_val, y_prediction)}')
print(MAE(np.exp(y_val), np.exp(y_prediction)), RMSE(np.exp(y_val), np.exp(y_prediction)))
# Out:
# The simple Linear Regression R-Square is: 0.6753101130164498
# 60.518497834950644 193.0953663237802

# %%
# We find a set of data which only consist of hotel prices below the max value
max_price = find_feature_limit(hotel_poly_df2, 'sales_price')[1]
hotel_poly_df2_filter = hotel_poly_df2[hotel_poly_df2.sales_price < max_price]

# %% [markdown]
# Let's apply Simple Linear Regression with polynomials features again with filtered price

# %%
X = hotel_poly_df2_filter.drop(['sales_price', 'log_price'], 1)
y = hotel_poly_df2_filter.log_price

# 60 - 20 - 20 (Train/Val/Test Split)
X, X_test, y, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state= 42)

# %%
lm_poly_filter = LinearRegression()

lm_poly_filter.fit(X_train, y_train)

y_prediction = lm_poly_filter.predict(X_val)
print(f'The simple Linear Regression R-Square is: {r2_score(y_val, y_prediction)}')
print(MAE(np.exp(y_val), np.exp(y_prediction)), RMSE(np.exp(y_val), np.exp(y_prediction)))
# Out:
# The simple Linear Regression R-Square is: 0.6414083107217008
# 32.446221399737 45.82379218155238

# %% [markdown]
# #### We will re-initialize the train/test/split data

# %%
X = hotel_poly_df2_filter.drop(['sales_price', 'log_price'], 1)
y = hotel_poly_df2_filter.log_price

# 60 - 20 - 20 (Train/Val/Test Split)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# #### Let's train using LassoCV

# %%
lasso_coef_poly = lasso_cv(X_train, y_train, alphavec)
# Out:
# The optimal alpha is 0.001
# The R-Squared is 0.6332744932931995
# The R-Squared value using CV is: 0.6265015948172431
# The MAE is 32.178164722988996 and the RMSE is 45.53504084648289

# %% [markdown]
# #### Let's train using RidgeCV

# %%
The optimal alpha is 0.032176417502507354
The RidgeCV Regression R-Squared is 0.6608291131779485
The R_Squared using CV is 0.6485117556688549
The MAE is 31.700909562093226 and the RMSE is 45.13067398251348

# %%
ridge_coef_poly = ridge_cv(X_train, y_train, alphavec)
# Out:
# The optimal alpha is 0.04247571552536898
# The RidgeCV Regression R-Squared is 0.6571222110114955
# The R_Squared using CV is 0.6473674503941804
# The MAE is 31.811443893214786 and the RMSE is 45.102590481301725

# %% [markdown]
# #### Let's train using ElasticNetCV

# %%
ElasticNet_coef_poly = ElasticNCV(X_train, y_train, alphavec)
# Out:
# The optimal alpha is 0.001
# The ElasticNetCV Regression R-Squared is: 0.6471115908097966
# The R-Squared using CV is 0.6389966012233332
# The MAE is 31.884004167195403 and RMSE is 45.29585857871166

# %% [markdown]
# ##### We used Lasso to determine which features are zeroed coefficient features. Let's remove all the zero-ed coefficient features and train our our data again using RidgeCV and ElasticNetCV

# %%
# Find all the beta coefficients which are zeros
non_zero_coef = [coef for coef in lasso_coef_poly[:][0] if abs(coef[1] == 0)]
zero_coef_features = [element[0] for element in non_zero_coef]
zero_coef_features;

# %%
# We will drop all the features we will not use for our features
zero_coef_features.extend(['sales_price', 'log_price'])
X_NZ = hotel_poly_df2_filter.drop(zero_coef_features ,axis = 1)
y_NZ = hotel_poly_df2_filter['log_price']

# We will reinitialize our train/test/split for new training
X_train_NZ, X_test_NZ, y_train_NZ, y_test_NZ = train_test_split(X_NZ, y_NZ, test_size=0.20, random_state=42)

# %% [markdown]
# #### Let's train on RidgeCV with non-zere beta coefficients

# %%
ridge_coef_poly_NZ = ridge_cv(X_train_NZ, y_train_NZ, alphavec)
# Out:
# The optimal alpha is 1.366716356462006
# The RidgeCV Regression R-Squared is 0.6409286512341997
# The R_Squared using CV is 0.63424197311112
# The MAE is 32.04396065209181 and the RMSE is 45.63549865568876

# %% [markdown]
# #### Let's train on ElasticNetCV with non-zere beta coefficients

# %%
ElasticNet_coef_poly_NZ = ElasticNCV(X_train_NZ, y_train_NZ, alphavec)
# Out:
# The optimal alpha is 0.001
# The ElasticNetCV Regression R-Squared is: 0.6395469582457887
# The R-Squared using CV is 0.6329963738257227
# The MAE is 32.03626160503892 and RMSE is 45.48903594922343

# %% [markdown]
# #### Let's re-visit our learning curve

# %%
import warnings
warnings.filterwarnings(action='ignore')
plot_learning_curve(RidgeCV(alphas = alphavec, cv = 5), 'Learning Rate of RidgeCV Model', X_train, y_train);

# %% [markdown]
# The learning curve indicates that we might be able to squeeze out more accuracy with more training examples. Let's increase our training set size to 90% and train on RidgeCV

# %%
# 60 - 20 - 20 (Train/Val/Test Split)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# %%
ridge_coef_poly2 = ridge_cv(X_train, y_train, alphavec)
# Out:
# The optimal alpha is 0.04247571552536898
# The RidgeCV Regression R-Squared is 0.6547885581572777
# The R_Squared using CV is 0.6476394800799359
# The MAE is 31.961736267313224 and the RMSE is 45.14935226333375

# %%
ridgeCV_betas_poly = ridge_coef_poly2[0]
ridgeCV_betas__poly_sorted = sorted(coef, key = lambda tuple: abs(tuple[1]), reverse = True)
ridgeCV_betas__poly_sorted;

# %%
ridgeCV_betas =

# %%
def gridsearchCV(X, y, params_dict, cv = 5, choice_model = ElasticNet()):
    
    # Scalar Transform input features
    std = StandardScaler()
    std.fit(X.values)
    X_train_scaled = std.transform(X.values)
    
    model = choice_model
    grid_model = GridSearchCV(estimator = model, param_grid = params_dict, cv = cv, scoring = 'r2')
    grid_model.fit(X_train_scaled, y)
    y_prediction = grid_model.predict(X_train_scaled)
    
    print(f'The optimal parameters are: {model_grid.best_estimators_}')
    print(f'The GridSearchCV Regression R-Squared is: {grid_model.best_score_}')
    
#     kf = KFold(n_splits = 5, shuffle = True, random_state = 101)
#     R_Squared = np.mean(cross_val_score(model, X_train_scaled, y, cv = kf, scoring = 'r2'))
#     print(f'The R_Squared value using GridSearch Regression for this model is : {R_Squared}')
#     print(f'The MAE is {MAE(np.exp(y), np.exp(y_prediction))} and RMSE is {RMSE(np.exp(y), np.exp(y_prediction))}')
#     coef_list = list(zip(X.columns, model.coef_))
    
#     return sorted(coef_list, key = lambda tuple: tuple[1], reverse = True), R_Squared

# %%
X = hotel_price_filter.drop(['sales_price', 'log_price'], 1)
y = hotel_price_filter['log_price']
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# parametersGrid = {"max_iter": [1, 5, 10],
#                   "alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100],
#                   "l1_ratio": np.arange(0.0, 1.0, 0.1)}

# %%
params_dict = {'alpha': list(10**np.linspace(-3,3,5)), 'l1_ratio': list(np.linspace(0,1,5))}
# gridCV_Elastic = gridsearchCV(X_train, y_train, params_dict = params_dict, cv = 5, choice_model = ElasticNet(max_iter = 10000))

# %%
# # Grid Search for Algorithm Tuning
# import numpy as np
# from sklearn import datasets
# from sklearn.linear_model import Ridge
# from sklearn.model_selection import GridSearchCV
# # load the diabetes datasets
# dataset = datasets.load_diabetes()
# # prepare a range of alpha values to test
# alphas = 10**np.linspace(-2,2,200)


# std = StandardScaler()
# std.fit(X_train.values)
# X_train_scaled = std.transform(X_train.values)
# # create and fit a ridge regression model, testing each alpha
# model = Ridge()
# grid = GridSearchCV(model, param_grid=dict(alpha=alphas))
# grid.fit(X_train_scaled, y_train)
# print(grid)
# # summarize the results of the grid search
# print(grid.best_score_)
# print(grid.best_estimator_)
# Out:
# /Users/bentleyou/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=None, normalize=False, random_state=None,
#                              solver='auto', tol=0.001),
#              iid='warn', n_jobs=None,
#              param_grid={'alpha': array([1.00000000e-02, 1.04737090e-02, 1.09698580e-02, 1.14895100e-02,
#        1.20337784e-02, 1.26038293e-02, 1.32008840e-02, 1.38262217...
#        4.15040476e+01, 4.34701316e+01, 4.55293507e+01, 4.76861170e+01,
#        4.99450512e+01, 5.23109931e+01, 5.47890118e+01, 5.73844165e+01,
#        6.01027678e+01, 6.29498899e+01, 6.59318827e+01, 6.90551352e+01,
#        7.23263390e+01, 7.57525026e+01, 7.93409667e+01, 8.30994195e+01,
#        8.70359136e+01, 9.11588830e+01, 9.54771611e+01, 1.00000000e+02])},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
# 0.6196922456890751
# Ridge(alpha=18.04186409392072, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
grid.coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-bdef3eb43ebb> in <module>()
# ----> 1 grid.coef_
#
# AttributeError: 'GridSearchCV' object has no attribute 'coef_'

# %%
grid.best_estimator_
# Out:
# Ridge(alpha=18.04186409392072, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
grid.best_estimator_.coef_
# Out:
# array([ 0.08189177,  0.04406303, -0.04266151,  0.05874051,  0.07199785,
#        -0.09276786,  0.12309547,  0.07186451, -0.02847328, -0.01744529,
#         0.02474071,  0.03764039, -0.00439865, -0.00724266, -0.00474575,
#         0.04513046,  0.01102043, -0.09814795,  0.03039673,  0.04714095,
#         0.0028557 , -0.02196308, -0.01575679, -0.01881344, -0.02745291,
#        -0.02014609, -0.02647878, -0.03712373, -0.01816238, -0.02077131,
#        -0.01482203, -0.01128709, -0.01677293, -0.01811652, -0.02060393,
#        -0.03077579, -0.035944  , -0.03568639, -0.04690794, -0.03181592,
#        -0.02572496, -0.01760168,  0.05880142, -0.03816341,  0.0482625 ,
#         0.04914739, -0.00953825,  0.03039673,  0.04714095,  0.0028557 ,
#        -0.02196308, -0.01575679, -0.01881344, -0.02745291, -0.02014609,
#        -0.02647878, -0.03712373, -0.01816238, -0.02077131, -0.01482203,
#        -0.01128709, -0.01677293, -0.01811652, -0.02060393, -0.03077579,
#        -0.035944  , -0.03568639, -0.04690794, -0.03181592, -0.02572496,
#        -0.01760168,  0.05880142, -0.03816341,  0.0482625 ,  0.04914739,
#        -0.00953825,  0.04413594,  0.03072705,  0.01954971, -0.01053677,
#         0.04121188,  0.01594187, -0.02526479, -0.01359876,  0.01565277,
#        -0.02119724,  0.00716347, -0.01752959,  0.02079407,  0.06610269,
#         0.03370047,  0.04351858,  0.02267284, -0.02232071,  0.001971  ,
#         0.0213603 ,  0.022018  , -0.02344478,  0.03866256, -0.00072553,
#         0.03547003,  0.00481244,  0.01804345,  0.0136009 ,  0.02656624,
#         0.05213153,  0.02601176, -0.03819279,  0.0467451 ,  0.0420243 ,
#        -0.00471387, -0.03277967, -0.03243689,  0.06205547, -0.03277967,
#        -0.03243689,  0.06205547, -0.08673813, -0.02683895])

# %%
list(np.linspace(0,1,20))
# Out:
# [0.0,
#  0.05263157894736842,
#  0.10526315789473684,
#  0.15789473684210525,
#  0.21052631578947367,
#  0.2631578947368421,
#  0.3157894736842105,
#  0.3684210526315789,
#  0.42105263157894735,
#  0.47368421052631576,
#  0.5263157894736842,
#  0.5789473684210527,
#  0.631578947368421,
#  0.6842105263157894,
#  0.7368421052631579,
#  0.7894736842105263,
#  0.8421052631578947,
#  0.894736842105263,
#  0.9473684210526315,
#  1.0]
