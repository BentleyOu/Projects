# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline
sns.set_style('whitegrid')

# %%
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, precision_recall_curve,f1_score, fbeta_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

# %%
booking_df = pd.read_pickle('booking_cleaned.pkl')

# %%
booking_df = pd.read_pickle('booking_notNan.pkl')

# %%
num_booker = booking_df[booking_df['booker'] == 1].shape[0]
num_non_booker = booking_df[booking_df['booker'] == 0].shape[0]
print(f'There is a total of {num_booker} positive class and {num_non_booker} negative class')
print(f'The ratio of negative:positive is {round(num_non_booker/num_booker, 4)}')
# Out:
# There is a total of 39452 positive class and 111470 negative class
# The ratio of negative:positive is 2.8255

# %%
booking_df['signup_flow'] = [str(x) for x in booking_df.signup_flow]

# %% [markdown]
# #### Let's define our features and targets

# %%
booking_df_dummies = pd.get_dummies(booking_df, drop_first = True)

# %%
X = booking_df_dummies.drop('booker', 1)
y = booking_df_dummies.booker

# %% [markdown]
# #### Train/Test Split

# %%
# 60-20-20 train-val-test split (stratify = target for balance positive examples)
X, X_test, y, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify = y)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=42, stratify = y)

# %% [markdown]
# #### Balance out the classes using ADASYN

# %%
from imblearn.over_sampling import ADASYN

X_adasyn_train, y_adasyn_train = ADASYN(random_state=42).fit_sample(X_train,y_train)

# %%
print(f'train set, positive class: {Counter(y_adasyn_train)[0]}, negative class: {Counter(y_adasyn_train)[1]}')
# Out:
# train set, positive class: 66881, negative class: 69685

# %% [markdown]
# #### Balance out the classes using SMOTE (Synthetic Minority Oversampling Technique)

# %%
from imblearn.over_sampling import SMOTE

X_smoted_train, y_smoted_train = SMOTE(random_state=42).fit_sample(X_train,y_train)

# %%
print(f'train set, positive class: {Counter(y_smoted_train)[0]}, negative class: {Counter(y_smoted_train)[1]}')
# Out:
# train set, positive class: 66881, negative class: 66881

# %% [markdown]
# #### Let's plot the heatmap of the feature correlations.

# %%
plt.figure(figsize = (16,16));
sns.heatmap(booking_df_dummies.corr(), cmap = 'seismic', vmin = -1, vmax = 1, square = True);

# %% [markdown]
# #### Create a helper function to calculate the score of a model

# %%
def score(X_train, y_train, X_val, y_val, model, threshold = 0.5):
    
#     print("Training: {:6.2f}%".format(100*model.score(X_train, y_train)))
#     print("Test set: {:6.2f}%".format(100*model.score(X_val, y_val)))
    
    logit_confusion = confusion_matrix(y_val, model.predict(X_val))
#     print("Precision: {:6.4f}, Recall: {:6.4f}".format(precision_score(y_val, logit.predict(X_val)), 
#                                                      recall_score(y_val, logit.predict(X_val))))
    
    f1score = f1_score(y_val, model.predict(X_val))
    
    y_train_pred = (model.predict_proba(X_train)[:,1] > threshold)
    y_val_pred = (model.predict_proba(X_val)[:,1] > threshold)

    
    scores = {'Training': [100*model.score(X_train,y_train),precision_score(y_train, y_train_pred),
                         recall_score(y_train, y_train_pred), f1_score(y_train, y_train_pred)],
              
            'Testing': [100*model.score(X_val,y_val),precision_score(y_val, y_val_pred),
                         recall_score(y_val, y_val_pred), f1_score(y_val, y_val_pred)]}
    
    score_df = pd.DataFrame(scores, index = ['Accuracy', 'Precision', 'Recall', 'F1_Score'])
    
    return score_df

# %% [markdown]
# #### Create a helper function to calculate the optimal threshold for the model

# %%
# We can also use the probabilities to make a curve showing us how recall 
# and thresholds trade off 
def plot_threshold_curve(X_val, y_val, model, title):
    precision_curve, recall_curve, threshold_curve = precision_recall_curve(y_val, model.predict_proba(X_val)[:,1]);

    plt.figure(dpi=80);
    plt.plot(threshold_curve, precision_curve[1:],label='precision');
    plt.plot(threshold_curve, recall_curve[1:], label='recall');
    plt.legend(loc='lower left');
    plt.xlabel('Threshold (above this probability, label as positive)');
    plt.title(f'Precision and Recall Curves using {title}');
    
    return plt;

# %% [markdown]
# #### Create helper function to calculate the ROC and calculate the ROC/AUC score

# %%
# Precision = TP / (TP + FP)
# Recall = TP/P = True positive rate
# false positive rate = FP / true negatives = FP / (FP + TN) 
from sklearn.metrics import roc_auc_score, roc_curve

def plot_ROC(X_val, y_val, model):

    fpr, tpr, thresholds = roc_curve(y_val, model.predict_proba(X_val)[:,1]);

    plt.plot(fpr, tpr,lw=2);
    plt.plot([0,1],[0,1],c='violet',ls='--');
    plt.xlim([-0.05,1.05]);
    plt.ylim([-0.05,1.05]);


    plt.xlabel('False positive rate');
    plt.ylabel('True positive rate');
    plt.title('ROC Curve');
    
    print("ROC AUC score = ", roc_auc_score(y_val, model.predict_proba(X_val)[:,1]))
    
    return roc_auc_score(y_val, model.predict_proba(X_val)[:,1])

# %% [markdown]
# ### Logistic Regression

# %%
# Using ADASYN data
# std_adasyn = StandardScaler()
# std_adasyn.fit(X_adasyn_train)
# X_adasyn_train_scaled = std_adasyn.transform(X_adasyn_train)
# X_val_adasyn_scaled = std_adasyn.transform(X_val)

logit_adasyn = LogisticRegression(solver = 'liblinear', max_iter = 100, class_weight='balanced', random_state= 42);
logit_adasyn.fit(X_adasyn_train, y_adasyn_train);

# %%
# Using SMOTED data
# std_smoted = StandardScaler()
# std_smoted.fit(X_smoted_train)
# X_smoted_train_scaled = std_smoted.transform(X_smoted_train)
# X_val_smoted_scaled = std_smoted.transform(X_val)

logit_smoted = LogisticRegression(solver = 'liblinear', max_iter = 100, class_weight = 'balanced')
logit_smoted.fit(X_smoted_train, y_smoted_train)
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [raw]
# # Find the optimal threshold for both the resampled and SMOTED data set
# plot_threshold_curve(X_adasyn_val, y_adasyn_val, logit_adasyn, 'logit_adasyn');
# plot_threshold_curve(X_smoted_val, y_smoted_val, logit_smoted, 'logit_smoted');

# %% [markdown]
# #### Using adasyn Logistic Regression

# %%
plot_threshold_curve(X_val, y_val, logit_adasyn, 'logit_adasyn')
# Out:
# <module 'matplotlib.pyplot' from '/Users/bentleyou/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
score(X_adasyn_train, y_adasyn_train, X_val, y_val, logit_adasyn, threshold = 0.50)
# print(classification_report(y_val, logit_adasyn.predict(X_val)))
# plot_ROC(X_val, y_val,logit_adasyn)
# Out:
#             Training    Testing
# Accuracy   62.749879  61.348352
# Precision   0.630827   0.363083
# Recall      0.650915   0.634728
# F1_Score    0.640714   0.461929

# %% [markdown]
# #### Using SMOTED Logistic Regression

# %%
# score(X_smoted_train, y_smoted_train, X_smoted_val, y_smoted_val, logit_smoted, threshold = 0.50)
print(classification_report(y_val, logit_smoted.predict(X_val)))
plot_ROC(X_val, y_val,logit_smoted)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.61      0.70     22295
#            1       0.36      0.63      0.46      7890
#
#     accuracy                           0.61     30185
#    macro avg       0.59      0.62      0.58     30185
# weighted avg       0.70      0.61      0.64     30185
#
# ROC AUC score =  0.6731725500127766
# 0.6731725500127766

# %%
# Percent of user who will make a booking
percent_booker = (56644/218732)


# By 2020, airbnb will have 3 million new users

num_new_bookers = round(3e6 * percent_booker)
print(f'There is a total of roughly 3million new users on airbnb in 2020.')
print(f'There is {num_new_bookers} potential new bookers in 2020')


# Average daily booking is $160.47 and airbnb roughly profits 20% from the booking price.
revenue_per_booker = round(0.2 * 160.47)

print(f'On average, the daily booking is $160.47 and airbnb roughly takes 20% from the booking price')
print(f'Roughly, there is $32 of revenue per user')


# Total potential profit = num_new_booker * profit_per_booker
total_revenue = num_new_bookers * revenue_per_booker
print(f'There is an estimated total of ${round(total_revenue)} in profit available in 2020 from {round(num_new_bookers)} new users with an estimated profit of ${revenue_per_booker} per new user!')

# Cost of advertising

cost_advertisement_per_user = 5

cost_of_total_advertisement = num_new_bookers * 5

print(cost_of_total_advertisement)

Cost_TP = cost_advertisement_per_user + 0.1 * revenue_per_booker
Cost_TN = 0
Cost_FP = cost_advertisement_per_user
Cost_FN = revenue_per_booker
      
Revenue_TP = revenue_per_booker
Revenue_TN = 0
Revenue_FP = 0
Revenue_FN = 0

print('\n')
print(f'The cost for True Postives: ${-Cost_TP}')
print(f'The cost for True Negatives: ${-Cost_TN}')
print(f'The cost for False Postives: ${-Cost_FP}')
print(f'The cost for False Negative: ${-Cost_FN}')
print('\n')
print(f'The revenue for True Postives: ${Revenue_TP}')
print(f'The revenue for True Negatives: ${Revenue_TN}')
print(f'The revenue for False Postives: ${Revenue_FP}')
print(f'The revenue for False Negative: ${Revenue_FN}')
# Out:
# There is a total of roughly 3million new users on airbnb in 2020.
# There is 776896 potential new bookers in 2020
# On average, the daily booking is $160.47 and airbnb roughly takes 20% from the booking price
# Roughly, there is $32 of revenue per user
# There is an estimated total of $24860672 in profit available in 2020 from 776896 new users with an estimated profit of $32 per new user!
# 3884480
#
#
# The cost for True Postives: $-8.2
# The cost for True Negatives: $0
# The cost for False Postives: $-5
# The cost for False Negative: $-32
#
#
# The revenue for True Postives: $32
# The revenue for True Negatives: $0
# The revenue for False Postives: $0
# The revenue for False Negative: $0

# %%
confusion_matrix(y_val, logit_smoted.predict(X_val))
# Out:
# array([[13570,  8725],
#        [ 2908,  4982]])

# %%
score(X_adasyn_train, y_adasyn_train, X_val, y_val, logit_adasyn, threshold = 0.50)['Training']
# Out:
# Accuracy     62.749879
# Precision     0.630827
# Recall        0.650915
# F1_Score      0.640714
# Name: Training, dtype: float64

# %%
np.linspace(0,1,26)
# Out:
# array([0.  , 0.04, 0.08, 0.12, 0.16, 0.2 , 0.24, 0.28, 0.32, 0.36, 0.4 ,
#        0.44, 0.48, 0.52, 0.56, 0.6 , 0.64, 0.68, 0.72, 0.76, 0.8 , 0.84,
#        0.88, 0.92, 0.96, 1.  ])

# %%
Cost_TP = cost_advertisement_per_user + 0.1 * revenue_per_booker
Cost_TN = 0
Cost_FP = cost_advertisement_per_user
Cost_FN = revenue_per_booker
      
Revenue_TP = revenue_per_booker
Revenue_TN = 0
Revenue_FP = 0
Revenue_FN = 0

for threshold in np.linspace(0,1,26):
    df_score = score(X_adasyn_train, y_adasyn_train, X_val, y_val, logit_adasyn, threshold = threshold)['training']
    df_score.iloc[]


num_TP = []
num_TN = []
num_FP = []
num_FN = []

Total = (num_TP * (Revenue_TP - Cost_TP) + 
         num_TN * (Revenue_TN - Cost_TN) + 
         num_FP * (Revenue_FP - Cost_FP) + 
         num_FN * (Revenue_FN - Cost_FN))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-286-acc70477fadd> in <module>()
#      19 Total = (num_TP * (Revenue_TP - Cost_TP) +
#      20          num_TN * (Revenue_TN - Cost_TN) +
# ---> 21          num_FP * (Revenue_FP - Cost_FP) +
#      22          num_FN * (Revenue_FN - Cost_FN))
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
feature_coef = []
for feature in zip(X.columns, logit_smoted.coef_.reshape(-1)):
    feature_coef.append(feature)

feature_coef_df = pd.DataFrame(feature_coef, columns = ['Features', 'Beta'])

# %%
feature_coef_Df = feature_coef_df.set_index('Features')
feature_coef_df.iloc[(-feature_coef_df['Beta'].abs()).argsort()].head(10)
# Out:
#                              Features      Beta
# 39                     signup_app_Web  0.683067
# 43      first_device_type_Mac Desktop  0.591719
# 46  first_device_type_Windows Desktop  0.516592
# 5              signup_method_facebook -0.381191
# 48           first_device_type_iPhone  0.271035
# 47             first_device_type_iPad  0.259267
# 14                      signup_flow_3  0.230987
# 9                      signup_flow_12  0.207280
# 12                     signup_flow_24  0.169316
# 8                       signup_flow_1 -0.167480

# %% [markdown]
# #### Using Support Vector Classifier

# %%
# from sklearn.svm import SVC
# from sklearn.preprocessing import MinMaxScaler

# # We also need to scale the data for SVM to converge much faster
# Xscaling_adasyn = MinMaxScaler(feature_range=(-1,1)).fit(X_adasyn_train)
# X_adasyn_train_scaled = Xscaling_adasyn.transform(X_adasyn_train)
# X_adasyn_val_scaled = Xscaling_adasyn.transform(X_adasyn_val)

# Xscaling_smoted = MinMaxScaler(feature_range=(-1,1)).fit(X_smoted_train)
# X_smoted_train_scaled = Xscaling_smoted.transform(X_smoted_train)
# X_smoted_val_scaled = Xscaling_smoted.transform(X_smoted_val)

# %%
# # Using adasyn Data
# SVC_clf = SVC(gamma = 'auto')
# SVC_adasyn = SVC_clf.fit(X_adasyn_train_scaled, y_adasyn_train)

# %%
# # Using smoted Data
# SVC_clf_smoted = SVC(gamma = 'auto')
# SVC_smoted = SVC_clf.fit(X_smoted_train_scaled, y_smoted_train)

# %% [markdown]
# ### Using Knn Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# #### KNN using adasyn

# %%
KNN = KNeighborsClassifier()
KNN_adasyn_clf = KNN.fit(X_adasyn_train, y_adasyn_train)

# %%
print(classification_report(y_val, KNN_adasyn_clf.predict(X_val)))
# plot_ROC(X_adasyn_val, y_adasyn_val, KNN_adasyn_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.57      0.65     22295
#            1       0.30      0.53      0.38      7890
#
#     accuracy                           0.56     30185
#    macro avg       0.54      0.55      0.52     30185
# weighted avg       0.65      0.56      0.58     30185

# %% [markdown]
# #### KNN using smoted

# %%
KNN_smoted = KNeighborsClassifier()
KNN_smoted_clf = KNN.fit(X_smoted_train, y_smoted_train)

# %%
print(classification_report(y_val, KNN_smoted_clf.predict(X_val)))
# plot_ROC(X_smoted_val, y_smoted_val, KNN_smoted_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.60      0.67     22295
#            1       0.30      0.49      0.38      7890
#
#     accuracy                           0.57     30185
#    macro avg       0.54      0.55      0.52     30185
# weighted avg       0.65      0.57      0.60     30185

# %% [markdown]
# ### Using Naive Bayes Classifer

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# #### MultinomialNB using adasyn

# %%
multiNB_adasyn = MultinomialNB()
multiNB_adasyn_clf = multiNB_adasyn.fit(X_adasyn_train, y_adasyn_train)

# %%
print(classification_report(y_val, multiNB_adasyn_clf.predict(X_val)))
plot_ROC(X_val, y_val, multiNB_adasyn_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.39      0.54     22295
#            1       0.32      0.80      0.45      7890
#
#     accuracy                           0.50     30185
#    macro avg       0.58      0.60      0.50     30185
# weighted avg       0.71      0.50      0.52     30185
#
# ROC AUC score =  0.6545724842395906
# 0.6545724842395906

# %% [markdown]
# #### MultinomialNB using smoted

# %%
multiNB_smoted = MultinomialNB()
multiNB_smoted_clf = multiNB_smoted.fit(X_smoted_train, y_smoted_train)

# %%
print(classification_report(y_val, multiNB_smoted_clf.predict(X_val)))
plot_ROC(X_val, y_val, multiNB_smoted_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.43      0.57     22295
#            1       0.32      0.77      0.45      7890
#
#     accuracy                           0.52     30185
#    macro avg       0.58      0.60      0.51     30185
# weighted avg       0.71      0.52      0.54     30185
#
# ROC AUC score =  0.6560991498090901
# 0.6560991498090901

# %% [markdown]
# #### BernoulliNB using adasyn

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
bernoulliNB_adasyn = BernoulliNB()
bernoulliNB_adasyn_clf = bernoulliNB_adasyn.fit(X_adasyn_train, y_adasyn_train)

# %%
print(classification_report(y_val, bernoulliNB_adasyn_clf.predict(X_val)))
plot_ROC(X_val, y_val, bernoulliNB_adasyn_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.39      0.53     22295
#            1       0.32      0.80      0.45      7890
#
#     accuracy                           0.50     30185
#    macro avg       0.58      0.59      0.49     30185
# weighted avg       0.71      0.50      0.51     30185
#
# ROC AUC score =  0.652795664540834
# 0.652795664540834

# %%
bernoulliNB_smoted = BernoulliNB()
bernoulliNB_smoted_clf = bernoulliNB_smoted.fit(X_smoted_train, y_smoted_train)

# %%
print(classification_report(y_val, bernoulliNB_smoted_clf.predict(X_val)))
plot_ROC(X_val, y_val, bernoulliNB_smoted_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.42      0.56     22295
#            1       0.32      0.77      0.46      7890
#
#     accuracy                           0.52     30185
#    macro avg       0.58      0.60      0.51     30185
# weighted avg       0.71      0.52      0.54     30185
#
# ROC AUC score =  0.6537342598427411
# 0.6537342598427411

# %% [markdown]
# #### GaussianNB using adasyn

# %%
gaussianNB_adasyn = GaussianNB()
gaussianNB_adasyn_clf = gaussianNB_adasyn.fit(X_adasyn_train, y_adasyn_train)

# %%
print(classification_report(y_val, gaussianNB_adasyn_clf.predict(X_val)))
plot_ROC(X_val, y_val, gaussianNB_adasyn_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.30      0.44     22295
#            1       0.30      0.86      0.45      7890
#
#     accuracy                           0.45     30185
#    macro avg       0.58      0.58      0.45     30185
# weighted avg       0.72      0.45      0.44     30185
#
# ROC AUC score =  0.6451720008606794
# 0.6451720008606794

# %% [markdown]
# #### GaussianNB using smoted

# %%
gaussianNB_smoted = GaussianNB()
gaussianNB_smoted_clf = gaussianNB_smoted.fit(X_smoted_train, y_smoted_train)

# %%
print(classification_report(y_val, gaussianNB_smoted_clf.predict(X_val)))
plot_ROC(X_val, y_val, gaussianNB_smoted_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.30      0.45     22295
#            1       0.30      0.86      0.45      7890
#
#     accuracy                           0.45     30185
#    macro avg       0.58      0.58      0.45     30185
# weighted avg       0.71      0.45      0.45     30185
#
# ROC AUC score =  0.6451106561372721
# 0.6451106561372721

# %% [markdown]
# ### Using Random Forest Classifer

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### RandomForest using adasyn

# %%
rf_adasyn = RandomForestClassifier(n_estimators=1000, max_features='sqrt', n_jobs = 3)
rf_adasyn_clf = rf_adasyn.fit(X_adasyn_train, y_adasyn_train)

# %%
print(classification_report(y_val, rf_adasyn_clf.predict(X_val)))
plot_ROC(X_val, y_val, rf_adasyn_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79     22295
#            1       0.36      0.28      0.32      7890
#
#     accuracy                           0.68     30185
#    macro avg       0.56      0.55      0.56     30185
# weighted avg       0.66      0.68      0.67     30185
#
# ROC AUC score =  0.604946623951047
# 0.6049466324782535

# %%
rf_smoted = RandomForestClassifier(n_estimators=1000, n_jobs = 3, max_features = 'sqrt')
rf_smoted_clf = rf_smoted.fit(X_smoted_train, y_smoted_train)

# %%
print(classification_report(y_val, rf_smoted_clf.predict(X_val)))
plot_ROC(X_val, y_val, rf_smoted_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79     22295
#            1       0.36      0.28      0.31      7890
#
#     accuracy                           0.68     30185
#    macro avg       0.56      0.55      0.55     30185
# weighted avg       0.66      0.68      0.67     30185
#
# ROC AUC score =  0.6051040191282295
# 0.6051040475522511

# %%
feature_importances = []
for feature in zip(X.columns, rf_smoted_clf.feature_importances_):
    feature_importances.append(feature)
    
feature_importance_df = pd.DataFrame(feature_importances, columns = ['Features', 'Importance'])

# %%
# Show the top most important features
feature_importance_df.set_index('Features').sort_values(by = 'Importance', ascending = False).head(10)
# Out:
#                                       Importance
# Features
# age                                     0.276778
# delta_account_created_first_activity    0.227682
# signup_method_facebook                  0.097955
# first_affiliate_tracked_untracked       0.047775
# gender_FEMALE                           0.039058
# gender_MALE                             0.032306
# signup_flow_3                           0.023127
# first_affiliate_tracked_omg             0.019085
# first_browser_Chrome                    0.016521
# signup_app_Web                          0.015000

# %% [markdown]
# ### Using XGBoost Classifer

# %%
from xgboost import XGBClassifier

# %% [markdown]
# #### XGBoost on adasyn

# %%
XGBoost_adasyn = XGBClassifier(silent=False, 
                      scale_pos_weight=1,
                      learning_rate=0.01,  
                      colsample_bytree = 0.4,
                      subsample = 0.8,
                      objective='binary:logistic', 
                      n_estimators=400, 
                      reg_alpha = 0.3,
                      max_depth=4, 
                      gamma=10)
XGBoost_adasyn_clf = XGBoost_adasyn.fit(X_adasyn_train, y_adasyn_train)

# %%
print(classification_report(y_val, XGBoost_adasyn_clf.predict(X_val.values)))
plot_ROC(X_val.values, y_val, XGBoost_adasyn_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.79     22295
#            1       0.40      0.38      0.39      7890
#
#     accuracy                           0.69     30185
#    macro avg       0.59      0.59      0.59     30185
# weighted avg       0.69      0.69      0.69     30185
#
# ROC AUC score =  0.6664423840818657
# 0.6664423840818657

# %% [markdown]
# #### XGBoost on smoted

# %%
XGBoost_smoted = XGBClassifier(n_estimators=400)
XGBoost_smoted_clf = XGBoost_smoted.fit(X_smoted_train, y_smoted_train)

# %%
print(classification_report(y_val, XGBoost_smoted_clf.predict(X_val.values)))
plot_ROC(X_val.values, y_val, XGBoost_smoted_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.83     22295
#            1       0.47      0.21      0.29      7890
#
#     accuracy                           0.73     30185
#    macro avg       0.62      0.56      0.56     30185
# weighted avg       0.69      0.73      0.69     30185
#
# ROC AUC score =  0.6748854554565736
# 0.6748854554565736

# %%
feature_importances = []
for feature in zip(X.columns, rf_smoted_clf.feature_importances_):
    feature_importances.append(feature)
    
feature_importance_df = pd.DataFrame(feature_importances, columns = ['Features', 'Importance'])

# %%
# Show the top most important features
feature_importance_df.set_index('Features').sort_values(by = 'Importance', ascending = False).head(10)
# Out:
#                                       Importance
# Features
# age                                     0.276778
# delta_account_created_first_activity    0.227682
# signup_method_facebook                  0.097955
# first_affiliate_tracked_untracked       0.047775
# gender_FEMALE                           0.039058
# gender_MALE                             0.032306
# signup_flow_3                           0.023127
# first_affiliate_tracked_omg             0.019085
# first_browser_Chrome                    0.016521
# signup_app_Web                          0.015000

# %% [markdown]
# #### Let's try using LGBM Classifer

# %%
import lightgbm as LGMBClassifer

# %%
lgbm_adasyn = XGBRFClassifier(n_estimators=200, subsample=0.8, gamma = 10, scale_pos_weight=1.5)
lgbm_adasyn_clf = lgbm_adasyn.fit(X_adasyn_train, y_adasyn_train)

# %%
print(classification_report(y_val, lgbm_adasyn_clf.predict(X_val.values)))
plot_ROC(X_val.values, y_val, lgbm_adasyn_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.58      0.68     22295
#            1       0.35      0.65      0.46      7890
#
#     accuracy                           0.60     30185
#    macro avg       0.59      0.61      0.57     30185
# weighted avg       0.70      0.60      0.62     30185
#
# ROC AUC score =  0.6479196856530605
# 0.6479196856530605

# %%
print(classification_report(y_val, lgbm_adasyn_clf.predict(X_val.values)))
plot_ROC(X_val.values, y_val, lgbm_adasyn_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.58      0.68     22295
#            1       0.35      0.64      0.45      7890
#
#     accuracy                           0.60     30185
#    macro avg       0.59      0.61      0.57     30185
# weighted avg       0.70      0.60      0.62     30185
#
# ROC AUC score =  0.6504253399015564
# 0.6504253399015564

# %% [markdown]
# ### Using Decision Trees Classifer

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# #### Decision Trees on adasyn

# %%
dt_adasyn = DecisionTreeClassifier(random_state= 42, max_features='sqrt')
dt_adasyn_clf = dt_adasyn.fit(X_adasyn_train, y_adasyn_train)

# %%
print(classification_report(y_val, dt_adasyn_clf.predict(X_val)))
plot_ROC(X_val, y_val, dt_adasyn_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.77     22295
#            1       0.33      0.30      0.32      7890
#
#     accuracy                           0.66     30185
#    macro avg       0.55      0.54      0.55     30185
# weighted avg       0.65      0.66      0.65     30185
#
# ROC AUC score =  0.5552955316585331
# 0.5552955316585331

# %% [markdown]
# #### Decision Trees on smoted

# %%
dt_smoted = DecisionTreeClassifier(random_state= 42, max_features='sqrt')
dt_smoted_clf = dt_smoted.fit(X_smoted_train, y_smoted_train)

# %%
print(classification_report(y_val, dt_smoted_clf.predict(X_val)))
plot_ROC(X_val, y_val, dt_smoted_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.77     22295
#            1       0.33      0.29      0.31      7890
#
#     accuracy                           0.66     30185
#    macro avg       0.54      0.54      0.54     30185
# weighted avg       0.65      0.66      0.65     30185
#
# ROC AUC score =  0.54976187207428
# 0.54976187207428

# %% [markdown]
# ### Using Catboost Classifer

# %%
booking_df['signup_flow'] = [str(x) for x in booking_df.signup_flow]

# %%
booking_df_xgb = booking_df.copy()

# %%
X_catboost = booking_df_xgb.drop('booker', 1)
y_catboost = booking_df_xgb.booker

X_catboost, X_test_catboost, y_catboost, y_test_catboost = train_test_split(X_catboost, y_catboost, test_size=0.20, random_state=42, stratify = y_catboost)
X_train_catboost, X_val_catboost, y_train_catboost, y_val_catboost = train_test_split(X_catboost, y_catboost, test_size=0.25, random_state=42, stratify = y_catboost)

# %%
booking_df_xgb_dummies = pd.get_dummies(booking_df_xgb)

# %% [markdown]
# ### Catboost using dummies and oversampling

# %%
X_catboost_d = booking_df_xgb_dummies.drop('booker', 1)
y_catboost_d = booking_df_xgb_dummies.booker

X_catboost_d, X_test_catboost_d, y_catboost_d, y_test_catboost_d = train_test_split(X_catboost_d, y_catboost_d, test_size=0.20, random_state=42, stratify = y_catboost_d)
X_train_catboost_d, X_val_catboost_d, y_train_catboost_d, y_val_catboost_d = train_test_split(X_catboost_d, y_catboost_d, test_size=0.25, random_state=42, stratify = y_catboost_d)

# %%
from imblearn.over_sampling import ADASYN

X_adasyn_train_catboost_d, y_adasyn_train_catboost_d = ADASYN(random_state=42).fit_sample(X_train_catboost_d,y_train_catboost_d)

# %% [markdown]
# #### Turn the dummies back into categorical data

# %%
gender = pd.Series(['gender_-unknown-','gender_FEMALE', 'gender_MALE', 'gender_OTHER'])
age = pd.Series(['age_Unknown','age_18-21', 'age_21-25', 'age_25-30', 'age_30-35','age_35-40', 'age_40-45', 'age_45-50', 'age_50-55', 'age_55-60','age_60-65', 'age_65+'])
signup_method = pd.Series(['signup_method_basic','signup_method_facebook', 'signup_method_google', 'signup_method_weibo'])
signup_flow = pd.Series(['signup_flow_0','signup_flow_1',
       'signup_flow_10', 'signup_flow_12', 'signup_flow_14', 'signup_flow_15',
       'signup_flow_16', 'signup_flow_2', 'signup_flow_20', 'signup_flow_21',
       'signup_flow_23', 'signup_flow_24', 'signup_flow_25', 'signup_flow_3',
       'signup_flow_4', 'signup_flow_5', 'signup_flow_6', 'signup_flow_8'])
language = pd.Series(['language_en', 'language_other'])
affiliate_channel = pd.Series(['affiliate_channel_api', 'affiliate_channel_content',
       'affiliate_channel_direct', 'affiliate_channel_other',
       'affiliate_channel_remarketing', 'affiliate_channel_sem-brand',
       'affiliate_channel_sem-non-brand', 'affiliate_channel_seo'])
affiliate_provider = pd.Series(['affiliate_provider_bing', 'affiliate_provider_craigslist',
       'affiliate_provider_direct', 'affiliate_provider_facebook',
       'affiliate_provider_google', 'affiliate_provider_miscellaneous',
       'affiliate_provider_other'])
first_affiliate_tracked = pd.Series(['first_affiliate_tracked_linked',
       'first_affiliate_tracked_local ops',
       'first_affiliate_tracked_marketing', 'first_affiliate_tracked_omg',
       'first_affiliate_tracked_product',
       'first_affiliate_tracked_tracked-other',
       'first_affiliate_tracked_untracked'])
signup_app = pd.Series(['signup_app_Android',
       'signup_app_Moweb', 'signup_app_Web', 'signup_app_iOS'])
first_device = pd.Series(['first_device_type_Android Phone', 'first_device_type_Android Tablet',
       'first_device_type_Desktop (Other)', 'first_device_type_Mac Desktop',
       'first_device_type_Other/Unknown',
       'first_device_type_SmartPhone (Other)',
       'first_device_type_Windows Desktop', 'first_device_type_iPad',
       'first_device_type_iPhone'])
first_browser = pd.Series(['first_browser_-unknown-',
       'first_browser_Android Browser', 'first_browser_Chrome',
       'first_browser_Chrome Mobile', 'first_browser_Firefox',
       'first_browser_IE', 'first_browser_Mobile Safari',
       'first_browser_Other', 'first_browser_Safari'])

cols = [gender, age, signup_method, signup_flow, language, affiliate_channel, affiliate_provider, first_affiliate_tracked, signup_app, first_device, first_browser]

# %%
def undummy_train(dummied_df, cols = cols):
    
    df = pd.DataFrame()
    for col in cols:
        untupled = pd.Series([x[0] for x in dummied_df.loc[:, col.values].idxmax(1)])
        df = pd.concat([df, untupled], 1)

    return df

# %%
def undummy(dummied_df, cols = cols):
    
    df = pd.DataFrame()
    for col in cols:
        
        df = pd.concat([df, dummied_df.loc[:, col.values].idxmax(1)], 1)

    return df

# %%
X_adasyn_train_d = pd.DataFrame(data = X_adasyn_train_catboost_d[0:,0:], columns = [list(X_train_catboost_d.columns)])

# %%
X_train_catboost_u = undummy_train(X_adasyn_train_d)
X_train_catboost_u = pd.concat([X_train_catboost_u, pd.Series(X_adasyn_train_catboost_d[:,0])], 1)
X_train_catboost_u.columns = booking_df.columns[:-1]
# X_train_catboost_u['booker'] = [1 if x == 1 else 0 for x in y_adasyn_train_catboost_d]
X_val_catboost_u = undummy(X_val_catboost_d)
X_val_catboost_u = pd.concat([X_val_catboost_u, X_val_catboost_d.iloc[:,0]], 1)
X_val_catboost_u.columns = booking_df.columns[:-1]
# X_val_catboost_u['booker'] = [1 if x == 1 else 0 for x in y_val_catboost_d]
X_test_catboost_u = undummy(X_test_catboost_d)
X_test_catboost_u = pd.concat([X_test_catboost_u, X_test_catboost_d.iloc[:,0]], 1)
X_test_catboost_u.columns = booking_df.columns[:-1]
# X_test_catboost_u['booker'] = [1 if x == 1 else 0 for x in y_test_catboost_d]

# %%
# delta_account_created_first_activity = pd.concat([pd.Series(X_adasyn_train_catboost_d[:,0]), X_val_catboost_d.iloc[:,0], 
#                                                   X_test_catboost_d.iloc[:,0]])

# %%
# make a list of all the catagorical features. Last column is not a cat feature.
booking_features = list(X_train_catboost_u.columns[:-1])

# %%
from catboost import CatBoostClassifier

catboost_adasyn = CatBoostClassifier(iterations=500,l2_leaf_reg=3, loss_function='Logloss', 
                                     cat_features=booking_features, learning_rate=0.03, 
                                     depth= 6, border_count=32, random_state = 69)
catboost_adasyn_clf = catboost_adasyn.fit(X_train_catboost_u, y_adasyn_train_catboost_d);
# Out:
# 0:	learn: 0.6881985	total: 154ms	remaining: 1m 16s
# 1:	learn: 0.6821598	total: 253ms	remaining: 1m 3s
# 2:	learn: 0.6765837	total: 385ms	remaining: 1m 3s
# 3:	learn: 0.6715859	total: 478ms	remaining: 59.2s
# 4:	learn: 0.6665970	total: 617ms	remaining: 1m 1s
# 5:	learn: 0.6616291	total: 702ms	remaining: 57.8s
# 6:	learn: 0.6556131	total: 811ms	remaining: 57.1s
# 7:	learn: 0.6504354	total: 928ms	remaining: 57.1s
# 8:	learn: 0.6458102	total: 1.05s	remaining: 57.1s
# 9:	learn: 0.6425660	total: 1.18s	remaining: 57.8s
# 10:	learn: 0.6381940	total: 1.29s	remaining: 57.5s
# 11:	learn: 0.6347624	total: 1.42s	remaining: 57.7s
# 12:	learn: 0.6309400	total: 1.54s	remaining: 57.9s
# 13:	learn: 0.6279626	total: 1.64s	remaining: 57.1s
# 14:	learn: 0.6248278	total: 1.75s	remaining: 56.7s
# 15:	learn: 0.6223946	total: 1.89s	remaining: 57.1s
# 16:	learn: 0.6201995	total: 2s	remaining: 57s
# 17:	learn: 0.6172297	total: 2.12s	remaining: 56.8s
# 18:	learn: 0.6154029	total: 2.25s	remaining: 56.9s
# ...

# %%
print(classification_report(y_val_catboost_d, catboost_adasyn_clf.predict(X_val_catboost_u)))

# (model.predict_proba(X_train)[:,1] > threshold)
plot_ROC(X_val_catboost_u, y_val_catboost_d, catboost_adasyn_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.68      0.77     44497
#            1       0.22      0.48      0.30      8080
#
#     accuracy                           0.65     52577
#    macro avg       0.55      0.58      0.53     52577
# weighted avg       0.78      0.65      0.70     52577
#
# ROC AUC score =  0.6407956248913877
# 0.6407956248913877

# %%
from catboost import CatBoostClassifier

cat_features = list(booking_df.drop(['booker', 'delta_account_created_first_activity', 'age'], 1).columns)
catboost = CatBoostClassifier(iterations=500,l2_leaf_reg=3, loss_function='Logloss', 
                                     cat_features=cat_features, learning_rate=0.03, 
                                     depth= 6, border_count=32, random_state = 69, verbose=False)
catboost_clf = catboost.fit(X_train_catboost, y_train_catboost);

# %%
print(classification_report(y_val_catboost, catboost_clf.predict(X_val_catboost)))

# (model.predict_proba(X_train)[:,1] > threshold)
plot_ROC(X_val_catboost, y_val_catboost, catboost_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.99      0.85     22295
#            1       0.63      0.07      0.13      7890
#
#     accuracy                           0.75     30185
#    macro avg       0.69      0.53      0.49     30185
# weighted avg       0.72      0.75      0.66     30185
#
# ROC AUC score =  0.6813027837634029
# 0.6813027837634029

# %%
print(classification_report(y_val_catboost, catboost_clf.predict_proba(X_val_catboost)[:,1] > 0.125))

# (model.predict_proba(X_train)[:,1] > threshold)
plot_ROC(X_val_catboost, y_val_catboost, catboost_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.15      0.25     22295
#            1       0.29      0.98      0.45      7890
#
#     accuracy                           0.37     30185
#    macro avg       0.62      0.56      0.35     30185
# weighted avg       0.79      0.37      0.30     30185
#
# ROC AUC score =  0.6813027837634029
# 0.6813027837634029

# %% [markdown]
# ### Using Neural Network Classifier

# %%
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# #### Neural Network using adasyn

# %%
nn_adasyn = MLPClassifier(warm_start=True, hidden_layer_sizes=(150,), solver='lbfgs')
nn_adasyn_clf = nn_adasyn.fit(X_adasyn_train, y_adasyn_train)

# %%
print(classification_report(y_val, nn_adasyn_clf.predict(X_val)))
plot_ROC(X_val, y_val, nn_adasyn_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.59      0.69     22295
#            1       0.36      0.64      0.46      7890
#
#     accuracy                           0.60     30185
#    macro avg       0.59      0.62      0.57     30185
# weighted avg       0.70      0.60      0.63     30185
#
# ROC AUC score =  0.666366725021183
# 0.666366725021183

# %% [markdown]
# #### Neural Network using smoted

# %%
nn_smoted = MLPClassifier(warm_start=True, hidden_layer_sizes=(150,), solver='lbfgs')
nn_smoted_clf = nn_smoted.fit(X_smoted_train, y_smoted_train)

# %%
print(classification_report(y_val, nn_smoted_clf.predict(X_val)))
plot_ROC(X_val, y_val, nn_smoted_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.61      0.70     22295
#            1       0.36      0.62      0.46      7890
#
#     accuracy                           0.62     30185
#    macro avg       0.59      0.62      0.58     30185
# weighted avg       0.70      0.62      0.64     30185
#
# ROC AUC score =  0.6682021749492844
# 0.6682021749492844

# %% [markdown]
# ### ROC AUC Between Models

# %%
models = [bernoulliNB_adasyn_clf, bernoulliNB_smoted_clf, multiNB_adasyn_clf, multiNB_smoted_clf, logit_adasyn, logit_smoted, gaussianNB_adasyn_clf, gaussianNB_smoted_clf,
          rf_adasyn_clf, rf_smoted_clf, dt_adasyn_clf, dt_smoted_clf, nn_adasyn_clf, nn_smoted_clf]
labels = ['BernoulliNB_adasyn', 'BernoulliNB_smoted','MultiNB_adasyn', 'MultiNB_smoted','Logistic_Regression_smoted', 'Logistic_Regression_adasyn', 
          'GaussianNB_adasyn', 'GaussianNB_smoted', 'RandomForest_adasyn', 'RandomForest_smoted', 'DecisionTree_adasyn',
          'DecisionTree_smoted', 'NeuralNet_MLP_adasyn', 'NeuralNet_MLP_smoted']
AUCs = []

lw = 2;

for model in models:
    auc = roc_auc_score(y_val, model.predict_proba(X_val)[:,1])
    AUCs.append(round(auc,3))

# %%
model_graph = []
for element in zip(models, labels, AUCs):
    
    model_graph.append(element)
    
sorted(model_graph, key=lambda tup: tup[2], reverse = True);

# %%
plt.figure(figsize = (14,12))
for model in zip(sorted_by_AUC):

    fpr, tpr, thresholds = roc_curve(y_val, model[0][0].predict_proba(X_val)[:,1])
    plt.plot(fpr, tpr,lw=lw, label = model[0][1] + f' = {model[0][2]}')
    
fpr_xgb_adasyn, tpr_xgb_adasyn, thresholds_xgb_adasyn = roc_curve(y_val, XGBoost_adasyn_clf.predict_proba(X_val.values)[:,1])
auc_xgb_adasyn = roc_auc_score(y_val, XGBoost_adasyn_clf.predict_proba(X_val.values)[:,1])
plt.plot(fpr_xgb_adasyn, tpr_xgb_adasyn,lw=lw, label = 'XGBoost_adasyn' + f' = {round(auc_xgb_adasyn,3)}')

fpr_xgb_smoted, tpr_xgb_smoted, thresholds_xgb_smoted = roc_curve(y_val, XGBoost_smoted_clf.predict_proba(X_val.values)[:,1])
auc_xgb_smoted = roc_auc_score(y_val, XGBoost_smoted_clf.predict_proba(X_val.values)[:,1])
plt.plot(fpr_xgb_smoted, tpr_xgb_smoted,lw=lw, label = 'XGBoost_smoted' + f' = {round(auc_xgb_smoted,3)}')

# fpr_logit_adasyn, tpr_logit_adasyn, thresholds_logit_adasyn = roc_curve(y_val, logit_adasyn.predict_proba(X_val_adasyn_scaled)[:,1])
# auc_logit_adasyn = roc_auc_score(y_val, logit_adasyn.predict_proba(X_val_adasyn_scaled)[:,1])
# plt.plot(fpr_logit_adasyn, tpr_logit_adasyn,lw=lw, label = 'Logit_adasyn' + f' = {round(auc_logit_adasyn,3)}')

# fpr_logit_smoted, tpr_logit_smoted, thresholds_logit_smoted = roc_curve(y_val, logit_adasyn.predict_proba(X_val_smoted_scaled)[:,1])
# auc_logit_smoted = roc_auc_score(y_val, logit_smoted.predict_proba(X_val_smoted_scaled)[:,1])
# plt.plot(fpr_logit_smoted, tpr_logit_smoted,lw=lw, label = 'Logit_adasyn' + f' = {round(auc_logit_smoted,3)}')

# fpr_xgb_smoted, tpr_xgb_smoted, thresholds_xgb_smoted = roc_curve(y_val, XGBoost_smoted_clf.predict_proba(X_val)[:,1])
# auc_xgb_smoted = roc_auc_score(y_val, XGBoost_smoted_clf.predict_proba(X_val.values)[:,1])
# plt.plot(fpr_xgb_smoted, tpr_xgb_smoted,lw=2, label = 'XGBoost_smoted' + f' = {round(auc_xgb_smoted,3)}')

        
plt.plot([0,1],[0,1],c='violet',ls='--', lw=lw);
plt.xlim([0,1.00]);
plt.ylim([0,1.00]);
plt.xlabel('False Positive Rate', size = 20);
plt.ylabel('True Positive Rate', size = 20);
plt.title('ROC Curve', size = 25);
plt.legend(loc = 'lower right', prop={'size': 15});
